# %% [markdown]
# <div class="alert alert-block alert-info">
# <h2>Week 9_Part2. Web Scraping by HTML Part 2</h2><br>
# <p>BeautifulSoup is great for small projects. Check on a good tutorial to improve your skills <a href="https://www.linode.com/docs/applications/big-data/how-to-scrape-a-website-with-beautiful-soup/">here</a>.</p>
# <p>Yet Scrapy would be a better option for large-scale scraping. You can use Scrapy to build and run your own web spiders.</p>
# <p>If your are interested in Scrapy, you can get it from <a href="https://scrapy.org/">here</a>.</p><br>
#     <p>In this session, we'll repeat how to request and parse HTML documents. Yet we'll also learn how to scrape off their content by selecting both HTML elements and their attributes such as <kbd class="alert-alert-block alert-success"><b>class</b></kbd>as in<kbd><b>p class="first"</b></kbd> to scrape off the specific content when the same HTML element may be used to mark up other content that we might want to leave out.</p><br>
# </div>

# %%
# Import the relevant libraries to scrape web content.

import requests as re

from bs4 import BeautifulSoup as bs

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>Go to the first page of Her reviews on the Rotten Tomatoes webpage. The url is in the code line below</h3>
#
# <p><a href="https://www.rottentomatoes.com/m/her/reviews/">https://www.rottentomatoes.com/m/her/reviews/</a></p><br>
#
# </div>

# %%
# Send a GET request to the first page that features reviews of the movie Her

url = re.get("https://www.rottentomatoes.com/m/her/reviews/")

# Check if HTTP responds correctly

url
# Out:
# <Response [200]>

# %%
# Store the html document of that page.

content = url.content

content
# Out:
# b'<!DOCTYPE html>\n<html lang="en"\n      dir="ltr"\n      xmlns:fb="http://www.facebook.com/2008/fbml"\n      xmlns:og="http://opengraphprotocol.org/schema/">\n\n    <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n\n        <!-- salt=lay-def-02-juRm -->\n        <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n        <meta http-equiv="x-ua-compatible" content="ie=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n\n        <title>Her - Movie Reviews</title>\n        <meta name="description" content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies & TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets">\n\n        \n            <link rel="canonical" href="https://www.rottentomatoes.com/m/her/reviews">\n        \n\n        \n            \n        \n\n        <link rel="shortcut icon" sizes="76x76" type="image/x-icon" href="https://www.rottentomatoes.com/assets/pizza-pie/images/favicon.ico">\n        \n\n        \n            <meta property="fb:app_id" content="326803741017">\n            <meta property="og:site_name" content="Rotten Tomatoes">\n            <meta property="og:title" content="Her - Movie Reviews">\n            <meta property="og:description" content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies & TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets">\n            <meta property="og:type" content="video.movie">\n            <meta property="og:url" content="https://www.rottentomatoes.com/m/her/reviews">\n            <meta property="og:image" content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg">\n            <meta property="og:locale" content="en_US">\n        \n\n        <meta name="twitter:card" content="">\n        <meta name="twitter:image" content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg">\n        <meta name="twitter:title" content="Her - Movie Reviews">\n        <meta name="twitter:text:title" content="Her - Movie Reviews">\n        <meta name="twitter:description" content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies & TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets">\n        <meta name="twitter:site" content="">\n\n        <link rel="manifest" href="https://www.rottentomatoes.com/assets/pizza-pie/manifest/manifest.json" />\n\n        <link rel="apple-touch-icon" href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-60.jpg">\n        <link rel="apple-touch-icon" sizes="152x152" href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-152.jpg">\n        <link rel="apple-touch-icon" sizes="167x167" href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-167.jpg">\n        <link rel="apple-touch-icon" sizes="180x180" href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-180.jpg">\n\n        <!-- JSON+LD -->\n        \n\n        \n        \n\n        <!-- Google webmaster tools -->\n        <meta name="google-site-verification" content="VPPXtECgUUeuATBacnqnCm4ydGO99reF-xgNklSbNbc" />\n\n        <!-- Bing webmaster tools -->\n        <meta name="msvalidate.01" content="034F16304017CA7DCF45D43850915323" />\n        <meta name="theme-color" content="#FA320A">\n\n        <!-- DNS prefetch -->\n        <meta http-equiv="x-dns-prefetch-control" content="on">\n        \n            <link rel="dns-prefetch" href="//www.rottentomatoes.com" />\n        \n        \n            <link rel="preconnect" href="//www.rottentomatoes.com" />\n        \n\n        \n        \n\n        \n    \n        <link rel="preload" href="/assets/pizza-pie/stylesheets/bundles/global.b8d57b2e684.css" as= ...

# %%
# Parse the HTML document with a parser to make the document traversible for extracting specific content

htmlDoc = bs(content, 'html5lib')

htmlDoc
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#
#         <!-- salt=lay-def-02-juRm -->
#         <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#         <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#         <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
#         <title>Her - Movie Reviews</title>
#         <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="description"/>
#
#
#             <link href="https://www.rottentomatoes.com/m/her/reviews" rel="canonical"/>
#
#
#
#
#
#
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/images/favicon.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
#
#
#
#             <meta content="326803741017" property="fb:app_id"/>
#             <meta content="Rotten Tomatoes" property="og:site_name"/>
#             <meta content="Her - Movie Reviews" property="og:title"/>
#             <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" property="og:description"/>
#             <meta content="video.movie" property="og:type"/>
#             <meta content="https://www.rottentomatoes.com/m/her/reviews" property="og:url"/>
#             <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" property="og:image"/>
#             <meta content="en_US" property="og:locale"/>
#
#
#         <meta content="" name="twitter:card"/>
#         <meta content="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/RT_TwitterCard_2018.jpg" name="twitter:image"/>
#         <meta content="Her - Movie Reviews" name="twitter:title"/>
#         <meta content="Her - Movie Reviews" name="twitter:text:title"/>
#         <meta content="Rotten Tomatoes, home of the Tomatometer, is the most trusted measurement of quality for Movies &amp; TV. The definitive site for Reviews, Trailers, Showtimes, and Tickets" name="twitter:description"/>
#         <meta content="" name="twitter:site"/>
#
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/manifest/manifest.json" rel="manifest"/>
#
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-60.jpg" rel="apple-touch-icon"/>
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-152.jpg" rel="apple-touch-icon" sizes="152x152"/>
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-167.jpg" rel="apple-touch-icon" sizes="167x167"/>
#         <link href="https://www.rottentomatoes.com/assets/pizza-pie/head-assets/images/apple-touch-icon-180.jpg" rel="apple-touch-icon" sizes="180x180"/>
#
#         <!-- JSON+LD -->
#
#
#
#
#
#         <!-- Google webmaster tools -->
#         <meta content="VPPXtECgUUeuATBacnqnCm4ydGO99reF-xgNklSbNbc" name="google-site-verification"/>
#
#         <!-- Bing webmaster tools -->
#         <meta content="034F16304017CA7DCF45D43850915323" name="msvalidate.01"/>
#         <meta content="#FA320A" name="theme-color"/>
#
#         <!-- DNS prefetch -->
#         <meta content="on" http-equiv="x-dns-prefetch-control"/>
#
#             <link href="//www.rottentomatoes.com" rel="dns-prefetch"/>
#
#
#             <link href="//www.rottentomatoes.com" rel="preconnect"/>
#
#
#
#
#
#
#
#         <link as="style" href="/assets/pizza-pie/stylesheets/bundles/global.b8d57b2e684.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#
#     <link as="style" href="/assets/pizza-pie/stylesheets/bundles/movie-reviews.657f1d60160.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#
#
#
#
#
#         <script>
#         !function(t){"use strict";t.loadCSS||(t.loadCSS=function(){});var e=loadCSS.relpreload={};if(e.support=function(){var e;try{e=t.document.createElement("link").relList.supports("preload")}catch(t){e=!1}return function(){return e}}(),e.bindMediaToggle=function(t){var e=t.media||"all";function a(){t.media=e}t.addEventListener?t.addEventListener("load",a):t.attachEvent&&t.attachEvent("onload",a),setTimeout(function(){t.rel="stylesheet",t.media="only x"}),setTimeout(a,3e3)},e.poly=function(){if(!e.support())for(var a=t.document.getElementsByTagName("link"),n=0;n<a.length;n++){var o=a[n];"preload"!==o.rel||"style"!==o.getAttribute("as")||o.getAttribute("data-loadcss")||(o.setAttribute("data-loadcss",!0),e.bindMediaToggle(o))}},!e.support()){e.poly();var a=t.setInterval(e.poly,500);t.addEventListener?t.addEventListener("load",function(){e.poly(),t.clearInterval(a)}):t.attachEvent&&t.attachEvent("onload",function(){e.poly(),t.clearInterval(a)})}"undefined"!=typeof exports?exports.loadCSS=loadCSS:t.loadCSS=loadCSS}("undefined"!=typeof global?global:this);
#         </script>
#
#         <script>window.RottenTomatoes = {};</script>
#         <script>window.RTLocals = {};</script>
#
#         <script>var dataLayer = dataLayer || [];</script>
#
#
#
#
#
#     <script id="mps-page-integration">
#       window.mpscall = {"adunits":"Multi Logo|Box Ad|Marquee Banner|Top Banner","cag[score]":"94","cag[certified_fresh]":"1","cag[fresh_rotten]":"fresh","cag[rating]":"R","cag[release]":"2013","cag[movieshow]":"Her","cag[genre]":"Drama|Science Fiction & Fantasy|Special Interest|Romance","cag[urlid]":"her","cat":"movie|reviews","field[env]":"production","field[rtid]":"771356295","path":"/m/her/reviews","site":"rottentomatoes-web","title":"Her","type":"webMovieReviews"};
#       var mpsopts={'host':'mps.nbcuni.com', 'updatecorrelator':1};
#       var mps=mps||{};mps._ext=mps._ext||{};mps._adsheld=[];mps._queue=mps._queue||{};mps._queue.mpsloaded=mps._queue.mpsloaded||[];mps._queue.mpsinit=mps._queue.mpsinit||[];mps._queue.gptloaded=mps._queue.gptloaded||[];mps._queue.adload=mps._queue.adload||[];mps._queue.adclone=mps._queue.adclone||[];mps._queue.adview=mps._queue.adview||[];mps._queue.refreshads=mps._queue.refreshads||[];mps.__timer=Date.now||function(){return+new Date};mps.__intcode="v2";if(typeof mps.getAd!="function")mps.getAd=function(adunit){if(typeof adunit!="string")return false;var slotid="mps-getad-"+adunit.replace(/\W/g,"");if(!mps._ext||!mps._ext.loaded){mps._queue.gptloaded.push(function(){typeof mps._gptfirst=="function"&&mps._gptfirst(adunit,slotid);mps.insertAd("#"+slotid,adunit)});mps._adsheld.push(adunit)}return'<div id="'+slotid+'" class="mps-wrapper" data-mps-fill-slot="'+adunit+'"></div>'};(function(){head=document.head||document.getElementsByTagName("head")[0],mpsload=document.createElement("script");mpsload.src="//"+mpsopts.host+"/fetch/ext/load-"+mpscall.site+".js?nowrite=2";mpsload.id="mps-load";head.insertBefore(mpsload,head.firstChild)})();
#     </script>
#
#
#     <script>
#         function endsWith(str, suffix) {
#             return str.indexOf(suffix, str.length - suffix.length) !== -1;
#         }
#
#         //--Ad Unit Loaded (called for each ad loaded)
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.adload = mps._queue.adload||[];
#         mps._queue.adload.push(function (eo) {
#             if (!eo.isEmpty) {
#                 var slotName = eo._mps._slot;
#
#                 if ('topbanner' === slotName) {
#                     var leaderboardHeight = eo.size[1];
#                     if (leaderboardHeight > 50){
#
#                             $('#header-main').removeClass('header_main_scroll');
#                             $('#header-main').css('margin-top', leaderboardHeight + 10);
#                             var bannerEl = $('#header_and_leaderboard');
#                             bannerEl.addClass('header_and_leaderboard_scroll');
#
#                         if (leaderboardHeight < 90){
#                             $('.leaderboard_wrapper').css('min-height', leaderboardHeight);
#                         }
#                         $('#top_leaderboard_wrapper').animate({ height: (leaderboardHeight + 10) },1000);
#                     }
#                 }
#
#                 if ('trendinggraphic' === slotName) {
#                     //Hide Trending bar social section
#                     $('#trending_bar_social').hide();
#                     // Roma version
#                     $('.trending-bar__social').hide();
#                     //Removing padding for trending bar ad
#                     $('.trendingBar > .trendingEl').css('padding','0px');
#                     $('#trending_bar_ad').show();
#
#                     $('a.trendingLink').addClass('trending-link-truncate');
#                     // Roma version
#                     $('.trending-bar__link').addClass('trending-link--truncate');
#                 }
#
#                 if ('tomatometer' === slotName) {
#                     if (eo.size[0] == 524 && eo.size[1] == 40) {
#                         //Increase score panel margin
#                         $('#scorePanel').css('margin-bottom', '20px');
#                     }
#                     // Only show Tomatometer Sponsorship div if rendered
#                     $('#tomatometer_sponsorship_ad').show();
#                 }
#             }
#         });
#     </script>
#
#
#
#
#
#
#
#
#             <script>
#                 dataLayer.push({"webVersion":"node","clicktale":true,"rtVersion":3,"loggedInStatus":"","customerId":"","pageName":"rt | movies | reviews | Her","titleType":"Movie","titleId":"771356295","titleName":"Her","titleGenre":"Drama|Science Fiction & Fantasy|Special Interest|Romance","lifeCycleWindow":"[on-dvd]","emsID":"658731ff-1c7d-3c09-9339-887185615355"});
#             </script>
#             <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-M5LKWCR');
#             </script>
#
#
#
#
#         <script type="text/javascript">!(function(o,n,t){t=o.createElement(n),o=o.getElementsByTagName(n)[0],t.async=1,t.src="https://honorableland.com/v2xglf05UGcVvzEUFlB6672D6fDwhuTsalYNh9J8Q6zzvZToUzEeznRfzQK-ELINP",o.parentNode.insertBefore(t,o)})(document,"script"),(function(o,n){o[n]=o[n]||function(){(o[n].q=o[n].q||[]).push(arguments)}})(window,"admiral");!(function(c,e,o,t,n){function r(o,t){(function n(){try{return 0<(localStorage.getItem("v4ac1eiZr0")||"").split(",")[4]}catch(o){}return!1})()&&(t=c[e].pubads())&&t.setTargeting("admiral-engaged","true")}(n=c[e]=c[e]||{}).cmd=n.cmd||[],typeof n.pubads===o?r():typeof n.cmd.unshift===o?n.cmd.unshift(r):n.cmd.push(r)})(window,"googletag","function");</script>
#
#
#
#         <script>
#             var ALGOLIA_INSIGHTS_SRC = "https://cdn.jsdelivr.net/npm/search-insights@1.5.0";
#
#             !function(e,a,t,n,s,i,c){e.AlgoliaAnalyticsObject=s,e[s]=e[s]||function(){
#             (e[s].queue=e[s].queue||[]).push(arguments)},i=a.createElement(t),c=a.getElementsByTagName(t)[0],
#             i.async=1,i.src=n,c.parentNode.insertBefore(i,c)
#             }(window,document,"script",ALGOLIA_INSIGHTS_SRC,"aa");
#         </script>
#
#
#
#
#     </head>
#     <body class="body no-touch">
#
#
#
#         <div id="emptyPlaceholder"></div>
#
#                 <script>
#                     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function()
#                     {n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}
#                     ;if(!f._fbq)f._fbq=n;
#                         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#                         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#                     fbq('init', '1147905821962466');
#                     fbq('track', 'PageView');
#                 </script>
#
#         <noscript>
#             <img height="1" src="https://www.facebook.com/tr?id=1147905821962466&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#         </noscript>
#
#
#             <script async="" src="//assets.adobedtm.com/launch-EN549327edc13e414a9beb5d61bfd9aac6.min.js"></script>
#
#
#
#             <!--BEGIN QUALTRICS WEBSITE FEEDBACK SNIPPET-->
# <script type="text/javascript">
#   (function(){var g=function(e,h,f,g){
#   this.get=function(a){for(var a=a+"=",c=document.cookie.split(";"),b=0,e=c.length;b<e;b++){for(var d=c[b];" "==d.charAt(0);)d=d.substring(1,d.length);if(0==d.indexOf(a))return d.substring(a.length,d.length)}return null};
#   this.set=function(a,c){var b="",b=new Date;b.setTime(b.getTime()+6048E5);b="; expires="+b.toGMTString();document.cookie=a+"="+c+b+"; path=/; "};
#   this.check=function(){var a=this.get(f);if(a)a=a.split(":");else if(100!=e)"v"==h&&(e=Math.random()>=e/100?0:100),a=[h,e,0],this.set(f,a.join(":"));else return!0;var c=a[1];if(100==c)return!0;switch(a[0]){case "v":return!1;case "r":return c=a[2]%Math.floor(100/c),a[2]++,this.set(f,a.join(":")),!c}return!0};
#   this.go=function(){if(this.check()){var a=document.createElement("script");a.type="text/javascript";a.src=g;document.body&&document.body.appendChild(a)}};
#   this.start=function(){var t=this;"complete"!==document.readyState?window.addEventListener?window.addEventListener("load",function(){t.go()},!1):window.attachEvent&&window.attachEvent("onload",function(){t.go()}):t.go()};};
#   try{(new g(100,"r","QSI_S_ZN_6SDb0uWojRgLmmN","https://zn6sdb0uwojrglmmn-fandango.siteintercept.qualtrics.com/SIE/?Q_ZID=ZN_6SDb0uWojRgLmmN")).start()}catch(i){}})();
#   </script><div id="ZN_6SDb0uWojRgLmmN"><!--DO NOT REMOVE-CONTENTS PLACED HERE--></div>
# <!--END WEBSITE FEEDBACK SNIPPET-->
#
#
#         <!-- mobile menu -->
#         <div aria-labelledby="navMenu" class="modal fade" id="navMenu" role="dialog">
#     <div class="modal-dialog">
#         <div class="modal-content">
#             <div class="modal-body">
#                 <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                     <span class="glyphicon glyphicon-remove">
#                 </span></button>
#                 <div class="pull-left">
#                     <ul class="list-inline social">
#                         <li><a class="header-facebook-social-link" href="//www.facebook.com/rottentomatoes" rel="noopener" target="_blank"></a></li>
#                         <li><a class="header-twitter-social-link" href="//twitter.com/rottentomatoes" rel="noopener" target="_blank"></a></li>
#                     </ul>
#                 </div>
#                 <div class="items">
#                     <div class="item">
#                         <a class="homeTab unstyled navLink fullLink" href="/">
#                             Home
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="boxofficeTab unstyled navLink fullLink" href="/lists/theater/">
#                             Top Box Office
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="theatersTab unstyled navLink fullLink" href="/theaters/">
#                             Tickets &amp; Showtimes
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="dvdTab unstyled navLink fullLink" href="/lists/dvd/">
#                             DVD &amp; Streaming
#                         </a>
#                     </div>
#                     <!-- <c:if test="${'us' eq headerInfo.i18nHeader or 'US' eq headerInfo.i18nHeader or '' eq headerInfo.i18nHeader}"> -->
#                         <div class="item">
#                             <a class="tvTab unstyled navLink fullLink" href="/lists/tv/">
#                                 TV
#                             </a>
#                         </div>
#                     <!-- </c:if> -->
#                     <div class="item">
#                         <a class="newsTab unstyled navLink fullLink" href="https://editorial.rottentomatoes.com/">
#                             News
#                         </a>
#                     </div>
#                     <!--
#                     <div class="item">
#                         <a class="newsletterTab unstyled navLink fullLink" href="/newsletter/">
#                             <%--Join Newsletter--%>
#                         </a>
#                     </div>
#                     -->
#                 </div>
#                 <div class="loginArea"></div>
#             </div>
#         </div>
#     </div>
# </div>
#
#
#         <div class="body_main container">
#
#             <div id="header_and_leaderboard">
#
#
#
#
#     <div class="leaderboard_wrapper" id="top_leaderboard_wrapper">
#         <div class="leaderboard_helper" id="top_leaderboard_helper">
#             <div id="leaderboard_top_ad"></div>
#             <script>
#                 //--RESPONSIVE AD SWITCHING (DIFFERENT CONTAINERS)
#                 var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function () {
#                     if (mps.getResponsiveSet() == '0') { //MOBILE
#                         mps.insertAd('#leaderboard_top_ad','mbanner');
#                     } else { //DESKTOP or TABLET
#                         mps.insertAd('#leaderboard_top_ad','topbanner');
#                     }
#                 });
#             </script>
#         </div>
#     </div>
#
#
#
#
#
#
#             </div>
#
#             <!-- global header -->
#             <nav class="header_main container" id="header-main">
#     <div class="navbar navbar-rt" id="navbar" role="navigation">
#         <div class="navbar-header pull-right hidden-xs">
#             <div class="header_links">
#                 <a href="/about#whatisthetomatometer" id="header-whats-the-tomatometer">What's the Tomatometer®?</a>
#                 <a href="/critics/" id="header-top-bar-critics">Critics</a>
#                 <div class="js-header-auth__user-section" id="headerUserSection" style="display: inline-block;">
#
#                         <a class="signupLink login ctHidden js-dtm-signup" data-target="#signup" data-toggle="modal" id="header-top-bar-signup">SIGN UP</a>
#
#                     |
#                     <a class="loginLink login ctHidden js-dtm-login" data-target="#login" data-toggle="modal" id="header-top-bar-login">LOG IN</a>
#                 </div>
#             </div>
#         </div>
#         <div class="col-sm-13 col-full-xs" id="header_brand_column">
#             <div class="hidden-xs desktopNav">
#                 <!-- Logo -->
#                 <div class="navbar-brand" id="navbar_brand">
#                     <a aria-label="header logo" class="header-rt-logo" href="/"><img alt="Rotten Tomatoes Logo" id="original_rt_logo" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/></a>
#
#
#
#
#
#     <div id="new_logo_ad" style="display:none;"></div>
#     <script>
#         var mps = mps||{}; mps._queue = mps._queue||{}; mps._queue.gptloaded = mps._queue.gptloaded||[];
#         mps._queue.gptloaded.push(function () {
#             mps.rt.insertlogo('#new_logo_ad', 'ploc=rtlogo;');
#         });
#     </script>
#
#
#                 </div>
#                 <search-algolia class="search-algolia search-algolia-desktop" hidden="">
#                     <search-algolia-controls slot="search-controls">
#                         <input class="search-text" data-qa="search-input" placeholder="Search movies, TV, actors, more..." slot="search-input" type="text"/>
#                         <button class="search-clear" data-qa="search-clear" slot="search-clear">
#                             <rt-icon icon="cancel-circled" image=""></rt-icon>
#                         </button>
#                         <a class="search-submit" data-qa="search-submit" href="/search" slot="search-submit">
#                             <rt-icon icon="search" image=""></rt-icon>
#                         </a>
#                     </search-algolia-controls>
#                     <search-algolia-results data-qa="search-results-overlay" slot="search-results">
#                         <search-algolia-results-category data-qa="search-results-category" slot="content">
#                             <h2 class="h2" data-qa="search-category-header" slot="title">Movies / TV</h2>
#                             <ul slot="results"></ul>
#                         </search-algolia-results-category>
#                         <search-algolia-results-category data-qa="search-results-category" slot="celebrity">
#                             <h2 class="h2" data-qa="search-category-header" slot="title">Celebrity</h2>
#                             <ul slot="results"></ul>
#                         </search-algolia-results-category>
#                         <search-algolia-results-category slot="none">
#                             <h2 class="h2" data-qa="search-no-results" slot="title">No Results Found</h2>
#                         </search-algolia-results-category>
#                         <a class="view-all" data-qa="search-view-all" href="/" slot="view-all">View All</a>
#                     </search-algolia-results>
#                 </search-algolia>
#             </div>
#             <div class="mobileNav">
#                 <div>
#                     <button aria-label="search button" class="pull-right button--link navbar-button searchButton" data-version="v3" id="mobile-search-algolia-btn">
#                         <em class="glyphicon glyphicon-search white"></em>
#                     </button>
#                 </div>
#                 <!-- Logo -->
#                 <div class="navbar-brand">
#                     <a aria-label="header logo" class="header-rt-logo" href="/"> <img alt="Rotten Tomatoes Logo" src="/assets/pizza-pie/images/rtlogo.9b892cff3fd.png"/></a>
#                 </div>
#                 <div class="js-mobile-nav__body" id="mobile-nav">
#                     <div class="mob-nav-bottom clearfix">
#                         <ul class="nav-list" id="nav-list">
#                             <li class="nav-item">
#                                 <a href="/"><i class="fontelloIcon icon-home"></i>Home</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a href="/browse/in-theaters/"><i class="fontelloIcon icon-boxoffice"></i>Box Office</a>
#                             </li>
#
#                             <li class="nav-item">
#                                 <a href="/browse/tv-list-2"><i class="fontelloIcon icon-tv2"></i>TV</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a href="/browse/top-dvd-streaming/"><i class="fontelloIcon icon-redeem"></i>DVD</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a class="menu-btn js-mobile-nav__more-btn" id="menu-btn">
#                                     <i class="fontelloIcon icon-more"></i>MORE
#                                 </a>
#                             </li>
#                         </ul>
#                     </div>
#                     <div class="mobile-nav-overlay" id="mobile-nav-overlay">
#                         <!--mobile dropdown-->
#                         <ul class="mobile-menu-panel">
#                             <li class="nav-item"><a href="//editorial.rottentomatoes.com">News</a></li>
#                             <li class="nav-item hide js-mobile-nav__menu-my-account"><a href="#">My Account</a></li>
#                             <li class="nav-item clearfix d-block">
#                                 <div class="login-signup-box pull-left">
#
#                                         <a class="signupLink login btn-login-signup js-dtm-signup-mobile" data-target="#signup" data-toggle="modal" id="mobile-signup-btn">SIGN UP</a>
#
#                                     <a class="loginLink login btn-login-signup js-dtm-login-mobile" data-target="#login" data-toggle="modal" id="mobile-login-btn">LOG IN</a>
#                                 </div>
#                                 <div class="social-media-box pull-right">
#                                     <a href="https://www.facebook.com/rottentomatoes">
#                                         <i aria-hidden="true" class="fontelloIcon icon-facebook-squared"></i>
#                                     </a>
#                                     <a href="https://twitter.com/rottentomatoes">
#                                         <i aria-hidden="true" class="fontelloIcon icon-twitter"></i>
#                                     </a>
#                                 </div>
#                             </li>
#                         </ul>
#                         <!--mobile dropdown end-->
#                     </div>
#                 </div>
#             </div>
#         </div>
#         <div class="navbar-nav col-sm-11 hidden-xs" id="menu">
#             <ul class="list-inline">
#                 <li class="menuHeader center dropdown noSpacing" id="movieHeaderMenu">
#                     <a class="white" href="/browse/opening/" id="movieMenu" role="button">
#                         Movies &amp; DVDs<span class="fontelloIcon icon-down-dir"></span>
#                     </a>
#                     <div aria-labelledby="movieMenu" class="dropdown-menu" role="menu">
#                         <div class="row-sameColumnHeight">
#                             <div class="col-xs-5 subnav">
#                                 <div class="innerSubnav">
#                                     <h2 class="title">Movies in Theaters</h2>
#                                     <ul class="list-unstyled" id="header-movies-in-theaters">
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/opening/">Opening This Week</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/in-theaters/">Top Box Office</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/upcoming/">Coming Soon to Theaters</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="//www.rottentomatoes.com/browse/box-office/">Weekend Earnings</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/cf-in-theaters/">Certified Fresh Movies</a>
#                                         </li>
#                                     </ul>
#                                 </div>
#                             </div>
#                             <div class="col-xs-5 subnav">
#                                 <div class="innerSubnav">
#                                     <a class="unstyled articleLink" href="/dvd/"><h2 class="title">On Dvd &amp; Streaming</h2></a>
#                                     <ul class="list-unstyled" id="header-on-dvd-streaming">
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=fandango_now">FandangoNOW</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=netflix_iw">Netflix Streaming</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=itunes">iTunes</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-all/?services=amazon_prime;amazon">Amazon and Amazon Prime</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/top-dvd-streaming/">Top DVD &amp; Streaming</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-new/">New Releases</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-upcoming/">Coming Soon to DVD</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/cf-dvd-streaming-all/">Certified Fresh Movies</a>
#                                         </li>
#                                         <li>
#                                             <a class="unstyled articleLink" href="/browse/dvd-streaming-all/">Browse All</a>
#                                         </li>
#                                     </ul>
#                                 </div>
#                             </div>
#                             <div class="col-xs-3 subnav">
#                                 <div class="innerSubnav">
#                                     <h2 class="title">More</h2>
#                                     <ul class="list-unstyled" id="header-movies-more">
#                                         <li><a class="unstyled articleLink" href="/top/">Top Movies</a></li>
#                                         <li><a class="unstyled articleLink" href="/trailers/">Trailers</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                             <div class="col-xs-11 subnav" id="cfp-movies-nav">
#
#                                     <h2 class="title">Certified Fresh Picks</h2>
#                                     <div class="freshPicks inDropdown" id="header-certified-fresh-picks">
#
#
#
#
#
#                                             <div class="cfpItem hidden-xs">
#     <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
#     <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/shirley_2020">
#
#             <p class="topText bold"></p>
#
#         <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
#             <img alt="Shirley" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/U-KHWkU2kq4Vu7IobcnulPafwHM=/fit-in/278x400/v1.bTsxMzQyMzQzNDtqOzE4NjUwOzEyMDA7MTM4NzsyMDQ4" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
#         </div>
#         <div class="movie_content_area">
#
#                 <span class="icon tiny certified"></span>
#                 <span class="tMeterScore">87%</span>
#
#         </div>
#         <p class="title noSpacing">Shirley</p>
#     </a>
# </div>
#
#
#
#
#
#
#
#                                             <div class="cfpItem hidden-xs">
#     <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
#     <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/da_5_bloods">
#
#             <p class="topText bold"></p>
#
#         <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
#             <img alt="Da 5 Bloods" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/IBJgD2cdffkawIjDiU7uECHph3Y=/fit-in/278x400/v1.bTsxMzQyMjIyODtqOzE4NjUwOzEyMDA7Mzc1OzU1Ng" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
#         </div>
#         <div class="movie_content_area">
#
#                 <span class="icon tiny certified"></span>
#                 <span class="tMeterScore">92%</span>
#
#         </div>
#         <p class="title noSpacing">Da 5 Bloods</p>
#     </a>
# </div>
#
#
#
#
#
#
#
#                                             <div class="cfpItem hidden-xs">
#     <!-- Hardcorded rt url so pageheader on editorial routes to rt too -->
#     <a class="unstyled articleLink cfpLinks" href="https://www.rottentomatoes.com/m/on_the_record">
#
#             <p class="topText bold"></p>
#
#         <div class="imgContainer cfp-img-container" id="dropdown-cfp-image">
#             <img alt="On the Record" class="js-lazyLoad cfp-header-img" data-src="https://resizing.flixster.com/7VNMubkNeT0jpd38drJunPRkkPw=/fit-in/278x400/v1.bTsxMzQzMjUyMTtqOzE4NjUwOzEyMDA7MTA4MDsxMzUw" src="/assets/pizza-pie/images/poster_default.c8c896e70c3.gif"/>
#         </div>
#         <div class="movie_content_area">
#
#                 <span class="icon tiny certified"></span>
#                 <span class="tMeterScore">99%</span>
#
#         </div>
#         <p class="title noSpacing">On the Record</p>
#     </a>
# </div>
#
#
#                                     </div>
#
#                             </div>
#                         </div>
#                     </div>
#                 </li>
#                 <li class="menuHeader center dropdown noSpacing dropdown-toggle">
#                    <a href="//www.rottentomatoes.com/top-tv/" id="tvMenu"> TV<span class="fontelloIcon icon-down-dir"></span></a>
#                     <div aria-labelledby="tvMenu" class="dropdown-menu" id="tvMenuDropdown" role="menu">
#                         <div class="row-sameColumnHeight">
#                             <div class="col-xs-7 subnav">
#
#
#                                     <div class="innerSubnav" id="header-tv-col1">
#                                         <h2 class="title">New TV Tonight</h2>
#                                         <table class="movie_list tv_list" id="tv-list-1">
#
#
#
#                                                 <tbody><tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/murder_on_middle_beach/s01">
#
#                 <span class="icon tiny fresh"></span>
#                 <span class="tMeterScore">100%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/murder_on_middle_beach/s01">
#
#                 Murder on Middle Beach
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/flesh_and_blood/s01">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">90%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/flesh_and_blood/s01">
#
#                 Flesh and Blood
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/euphoria/s01">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">82%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/euphoria/s01">
#
#                 Euphoria
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_reagans/s01">
#
#                 <span class="icon tiny fresh"></span>
#                 <span class="tMeterScore">80%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_reagans/s01">
#
#                 The Reagans
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/fargo/s04">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">81%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/fargo/s04">
#
#                 Fargo
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_undoing/s01">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">75%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_undoing/s01">
#
#                 The Undoing
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/moonbase_8/s01">
#
#                 <span class="icon tiny fresh"></span>
#                 <span class="tMeterScore">61%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/moonbase_8/s01">
#
#                 Moonbase 8
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_walking_dead_world_beyond/s01">
#
#                 <span class="icon tiny rotten"></span>
#                 <span class="tMeterScore">41%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_walking_dead_world_beyond/s01">
#
#                 The Walking Dead: World Beyond
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/pandora/s02">
#
#                 <span class="tMeterIcon tiny noRating">No Score Yet</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/pandora/s02">
#
#                 Pandora
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_spanish_princess/s02">
#
#                 <span class="tMeterIcon tiny noRating">No Score Yet</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_spanish_princess/s02">
#
#                 The Spanish Princess
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_circus_inside_the_greatest_political_show_on_earth/s05">
#
#                 <span class="tMeterIcon tiny noRating">No Score Yet</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_circus_inside_the_greatest_political_show_on_earth/s05">
#
#                 The Circus: Inside the Wildest Political Show on Earth
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_eric_andre_show/s05">
#
#                 <span class="tMeterIcon tiny noRating">No Score Yet</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_eric_andre_show/s05">
#
#                 The Eric Andre Show
#
#         </a>
#     </td>
# </tr>
#
#
#                                         </tbody></table>
#                                         <div class="header-view-all-wrap">
#                                             <a class="header-view-all-link" href="/browse/tv-list-1/">View All</a>
#                                         </div>
#                                     </div>
#
#                             </div>
#                             <div class="col-xs-7 subnav">
#
#
#                                     <div class="innerSubnav" id="header-tv-col2">
#                                         <h2 class="title">Most Popular TV on RT</h2>
#                                         <table class="movie_list tv_list" id="tv-list-2">
#
#
#
#                                                 <tbody><tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_queens_gambit/95809">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">99%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_queens_gambit/95809">
#
#                 The Queen's Gambit
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/murder_on_middle_beach/s01">
#
#                 <span class="icon tiny fresh"></span>
#                 <span class="tMeterScore">100%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/murder_on_middle_beach/s01">
#
#                 Murder on Middle Beach
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_flight_attendant/98470">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">98%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_flight_attendant/98470">
#
#                 The Flight Attendant
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/the_undoing/s01">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">75%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
#         <a data-qa="sidebar-list-item-link" href="/tv/the_undoing/s01">
#
#                 The Undoing
#
#         </a>
#     </td>
# </tr>
#
#
#
#
#                                                 <tr class="tv_show_tr tvTopListTitle" data-qa="sidebar-list-item">
#     <td class="left_col">
#         <a href="/tv/dash_lily/s01">
#
#                 <span class="icon tiny certified_fresh"></span>
#                 <span class="tMeterScore">100%</span>
#
#         </a>
#     </td>
#     <td class="middle_col">
# ...
#         Copyright © Fandango. All rights reserved. <span class="version">V3</span>
#         <ul class="footer-legal__list">
#             <li class="footer-legal__list-item">
#                 <a class="footer-legal__link" href="//www.fandango.com/PrivacyPolicy" id="footer-privacy">
#                     Privacy Policy
#                 </a> |
#             </li>
#             <li class="footer-legal__list-item"><a class="footer-legal__link" href="//www.fandango.com/terms-and-policies" id="footer-tos">Terms and Policies</a> |</li>
#             <li class="footer-legal__list-item"><a class="footer-legal__link" href="//www.fandango.com/donotsellmyinfo">Do Not Sell My Info</a> |</li>
#             <li class="footer-legal__list-item"><a class="footer-legal__link" href="https://www.fandango.com/policies/cookies-and-tracking#cookie_management">AdChoices</a></li>
#         </ul>
#     </div>
# </footer>
#
# <footer class="footer-mobile visible-xs-block">
#     <div class="white">Copyright © Fandango. All rights reserved. <span class="version">V3</span></div>
#     <div class="default-margin">
#       <button class="btn btn-primary newsletter-btn" data-target="#signup" data-toggle="modal">Join Newsletter</button>
#       <a class="btn btn-primary newsletter-btn hide" href="https://optout.services.fandango.com/rottentomatoes">Join Newsletter</a>
#     </div>
#     <ul class="footer-mobile-legal__list">
#         <li class="footer-mobile-legal__list-item"><a class="footer-mobile-legal__link" href="//www.fandango.com/terms-and-policies">Terms and Policies</a></li>
#         <li class="footer-mobile-legal__list-item">
#             <a class="footer-mobile-legal__link" href="//www.fandango.com/PrivacyPolicy">
#                 Privacy Policy
#             </a>
#         </li>
#         <li class="footer-mobile-legal__list-item"><a class="footer-mobile-legal__link" href="//www.fandango.com/donotsellmyinfo">Do Not Sell My Info</a></li>
#         <li class="footer-mobile-legal__list-item" id="footer-feedback-mobile">
#
#         </li>
#     </ul>
# </footer>
#         </div>
#
#         <div class="modal fade" id="newTrailerModal" tabindex="-1">
#     <div class="modal-dialog modal-lg">
#
#         <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
#         <div id="videoPlayer" style="width:100%;height:100%"></div>
#     </div>
#     <div class="fullWidth">
#         <div class="btn btn-primary-rt closeBtn">
#             <span class="glyphicon glyphicon-chevron-left"></span> Go back
#         </div>
#         <div class="moreTrailer">
#             <a class="btn btn-primary-rt" href="/trailers/">More trailers <span class="glyphicon glyphicon-chevron-right"></span></a>
#         </div>
#     </div>
# </div>
#
#         <div class="modal fade" id="newIframeTrailerModal" tabindex="-1">
#     <div class="modal-dialog modal-lg">
#         <div class="closebutton"><span class="glyphicon glyphicon-remove-circle lightGray"></span></div>
#         <iframe id="iframeVideoPlayer" src="about:none" style="width:100%;height:100%"></iframe>
#     </div>
# </div>
#
#
#         <!-- Blue Kai -->
#
#             <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
#
#         <!-- End Blue Kai -->
#
#         <!-- <bootstrap:bodyScript /> -->
#
#
#
#         <script type="text/javascript">
# (function (root) {
# /* -- Data -- */
# root.RottenTomatoes || (root.RottenTomatoes = {});
# root.RottenTomatoes.context = {"_routes":{"adminManagePeople":{"path":"https:\u002F\u002Fadmin.flixster.com\u002Fadmin\u002Fmanage-people?id=:id","tokens":[{"literal":"https:\u002F\u002Fadmin.flixster.com\u002Fadmin\u002Fmanage-people?id="},{"key":"id"}]},"adminMerge":{"path":"https:\u002F\u002Fadmin.flixster.com\u002Factor\u002Fmerge?from=:id","tokens":[{"literal":"https:\u002F\u002Fadmin.flixster.com\u002Factor\u002Fmerge?from="},{"key":"id"}]},"baseCanonicalUrl":{"path":"https:\u002F\u002Fwww.rottentomatoes.com","tokens":[{"literal":"https:\u002F\u002Fwww.rottentomatoes.com"}]},"editorialPageCodeOfConduct":{"path":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fotg-article\u002Fcommunity-code-of-conduct","tokens":[{"literal":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fotg-article\u002Fcommunity-code-of-conduct"}]},"editorialPageProductBlog":{"path":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-product-blog","tokens":[{"literal":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-product-blog"}]},"flixsterGeoLocationApi":{"path":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip","tokens":[{"literal":"https:\u002F\u002Fapi.flixster.com\u002Fticketing\u002Fapi\u002Fv1\u002Fgeoip"}]},"napiAudience":{"path":"\u002Fnapi\u002FaudienceScore\u002F:id","tokens":[{"literal":"\u002Fnapi\u002FaudienceScore\u002F"},{"key":"id"}]},"napiAccountForgotPW":{"path":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FforgotPassword\u002F"}]},"napiAccountLogin":{"path":"\u002Fnapi\u002Faccount\u002Flogin\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogin\u002F"}]},"napiAccountLoginFacebookOauth":{"path":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FloginFacebookOauth\u002F"}]},"napiAccountLogout":{"path":"\u002Fnapi\u002Faccount\u002Flogout\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Flogout\u002F"}]},"napiAccountRegister":{"path":"\u002Fnapi\u002Faccount\u002Fregister\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002Fregister\u002F"}]},"napiAccountThemePreferences":{"path":"\u002Fnapi\u002Fpreferences\u002Fthemes","tokens":[{"literal":"\u002Fnapi\u002Fpreferences\u002Fthemes"}]},"napiAccountVerifyToken":{"path":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F","tokens":[{"literal":"\u002Fnapi\u002Faccount\u002FverifyToken\u002F"}]},"napiAdminMovieDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FmovieDetailPage\u002F:id\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FmovieDetailPage\u002F"},{"key":"id"},{"literal":"\u002Fmenu"}]},"napiAdminTvEpisodeDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvEpisodeDetailPage\u002F:episodeId\u002F:seasonId\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvEpisodeDetailPage\u002F"},{"key":"episodeId"},{"literal":"\u002F"},{"key":"seasonId"},{"literal":"\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAdminTvSeasonDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F:seasonId\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F"},{"key":"seasonId"},{"literal":"\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAdminTvSeriesDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F:seriesId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FtvSeasonDetailPage\u002F"},{"key":"seriesId"},{"literal":"\u002Fmenu"}]},"napiAdminFranchiseDetailMenu":{"path":"\u002Fnapi\u002Fadmin\u002FfranchiseDetailPage\u002F:franchiseId\u002Fmenu","tokens":[{"literal":"\u002Fnapi\u002Fadmin\u002FfranchiseDetailPage\u002F"},{"key":"franchiseId"},{"literal":"\u002Fmenu"}]},"napiAutocomplete":{"path":"\u002Fnapi\u002Flocation\u002Fautocomplete\u002F:text","tokens":[{"literal":"\u002Fnapi\u002Flocation\u002Fautocomplete\u002F"},{"key":"text"}]},"napiReviewFlag":{"path":"\u002Fnapi\u002Freview ...
# root.RottenTomatoes.context || (root.RottenTomatoes.context = {});
# root.RottenTomatoes.context.req = {"params":{"vanity":"her"},"queries":{},"route":{},"url":"\u002Fm\u002Fher\u002Freviews","secure":false,"buildVersion":undefined};
# root.RottenTomatoes.context.config = {};
# root.BK = {"PageName":"http:\u002F\u002Fwww.rottentomatoes.com\u002Fm\u002Fher\u002Freviews","SiteID":37528,"SiteSection":""};
# root.RottenTomatoes.thirdParty = {"chartBeat":{"auth":"64558","domain":"rottentomatoes.com"},"facebook":{"appId":"326803741017","version":"v6.0","appName":"flixstertomatoes"},"googleReCaptcha":"6Lcobh0TAAAAAN1K9rWeJ8xgl8uYkASWSDLBuKU1","mpx":{"accountPid":"NGweTC","playerPid":"y__7B0iQTi4P","accountId":"2474312077"},"algoliaSearch":{"aId":"79FRDP12PN","sId":"175588f6e5f8319b27702e4cc4013561"},"cognito":{"upId":"us-west-2_EzOtWn0cs","clientId":"omco3pjcakqgrjn2o257hu9r5"}};
# root.RottenTomatoes.serviceWorker = {"isServiceWokerOn":true};
# root.RottenTomatoes.context.useCognito = false;
# root.RottenTomatoes.context.disableFeatureDetection = false;
# root.RottenTomatoes.context.shell = {"header":{"trending":[{"id":"3714","type":"promoItem","image":null,"sequence":1,"promoSection":"102","header":"RT Podcast","startTime":"2019-08-20T17:00:00-07:00","body":null,"siteImageId":null,"startDate":null,"objectId":null,"subHeader":null,"url":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Farticle\u002Frotten-tomatoes-is-wrong-a-podcast-from-rotten-tomatoes\u002F","objectType":null},{"id":"3590","type":"promoItem","image":null,"sequence":2,"promoSection":"102","header":"Holiday Movie Guide","startTime":"2018-02-02T16:00:00-08:00","body":null,"siteImageId":null,"startDate":null,"objectId":null,"subHeader":null,"url":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Frt-hub\u002Fholiday-movie-guide-2020\u002F","objectType":null},{"id":"3719","type":"promoItem","image":null,"sequence":3,"promoSection":"102","header":"Holiday TV Calendar","startTime":"2019-09-29T17:00:00-07:00","body":null,"siteImageId":null,"startDate":null,"objectId":null,"subHeader":null,"url":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Farticle\u002F2020-holiday-tv-calendar\u002F","objectType":null},{"id":"3743","type":"promoItem","image":null,"sequence":4,"promoSection":"102","header":"Best Netflix Series","startTime":"2020-10-01T17:00:00-07:00","body":null,"siteImageId":null,"startDate":null,"objectId":null,"subHeader":null,"url":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Fguide\u002Fbest-netflix-shows-and-movies-to-binge-watch-now\u002F","objectType":null}],"certifiedMedia":{"certifiedFreshMovieInTheater":{"id":"2430","type":"promoItem","image":null,"sequence":1,"promoSection":"37","header":null,"startTime":"2013-12-01T16:00:00-08:00","body":null,"siteImageId":null,"startDate":"2013-12-01T16:00:00-08:00","objectId":"771517667","subHeader":"Theaters","url":null,"objectType":"2","media":{"url":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fm\u002Fshirley_2020","name":"Shirley","score":87,"posterImg":"https:\u002F\u002Fresizing.flixster.com\u002FU-KHWkU2kq4Vu7IobcnulPafwHM=\u002Ffit-in\u002F278x400\u002Fv1.bTsxMzQyMzQzNDtqOzE4NjUwOzEyMDA7MTM4NzsyMDQ4"}},"certifiedFreshMovieInTheater4":{"id":"3036","type":"promoItem","image":null,"sequence":1,"promoSection":"49","header":null,"startTime":"2014-09-16T17:00:00-07:00","body":null,"siteImageId":null,"startDate":null,"objectId":"771521835","subHeader":null,"url":null,"objectType":"2","media":{"url":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fm\u002Fda_5_bloods","name":"Da 5 Bloods","score":92,"posterImg":"https:\u002F\u002Fresizing.flixster.com\u002FIBJgD2cdffkawIjDiU7uECHph3Y=\u002Ffit-in\u002F278x400\u002Fv1.bTsxMzQyMjIyODtqOzE4NjUwOzEyMDA7Mzc1OzU1Ng"}},"certifiedFreshMovieAtHome":{"id":"2429","type":"promoItem","image":null,"sequence":1,"promoSection":"47","header":null,"startTime":"2013-12-01T16:00:00-08:00","body":null,"siteImageId":null,"startDate":"2013-12-01T16:00:00-08:00","objectId":"771517643","subHeader":"On DVD & Streaming","url":null,"objectType":"2","media":{"url":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fm\u002Fon_the_record","name":"On the Record","score":99,"posterImg":"https:\u002F\u002Fresizing.flixster.com\u002F7VNMubkNeT0jpd38drJunPRkkPw=\u002Ffit-in\u002F278x400\u002Fv1.bTsxMzQzMjUyMTtqOzE4NjUwOzEyMDA7MTA4MDsxMzUw"}},"certifiedFreshTvSeason":{"id":"2428","type":"promoItem","image":null,"sequence":1,"promoSection":"48","header":null,"startTime":"2013-12-01T16:00:00-08:00","body":null,"siteImageId":null,"startDate":"2013-12-01T16:00:00-08:00","objectId":"90702","subHeader":null,"url":null,"objectType":"22","media":{"url":"\u002Ftv\u002Fi_may_destroy_you\u002Fs01","name":"I May Destroy You","score":97,"posterImg":"https:\u002F\u002Fresizing.flixster.com\u002FNn-myLjZ8BJ19Phdi_acpUVzXKU=\u002Ffit-in\u002F278x400\u002Fv1.dDs3MTM3ODg7ajsxODYzODsxMjAwOzIwMDA7MzAwMA"}}},"tvLists":{"newTvTonight":{"categoryId":"1","id":"9314","mediaListItems":[{"id":"182937","type":"mediaListItem","sortkey":1,"mediaListId":"9314","mediaType":"S ...
# root.RottenTomatoes.context.movieReview = {"title":"Her","movieId":"658731ff-1c7d-3c09-9339-887185615355","type":"all","reviewsCount":20,"pageInfo":null,"reviewerDefaultImg":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fstatic\u002Fimages\u002Fredesign\u002Factor.default.tmb.gif","reviewerDefaultImgWidth":100};
# root.RottenTomatoes.context.useCursorPagination = false;
# root.RottenTomatoes.context.verifiedTooltip = {"verifiedTabTop":"Now you can see reviews for those we've verified to have purchased tickets to this movie.","verifiedTabTopLinkURL":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Farticle\u002Fintroducing-verified-audience-score\u002F","verifiedTabTopLinkText":"Learn more","verifiedTabTopLinkVisible":true,"verifiedTooltipTop":"This person bought a ticket to see this movie.","verifiedTooltipTopLinkURL":"https:\u002F\u002Feditorial.rottentomatoes.com\u002Farticle\u002Fintroducing-verified-audience-score\u002F","verifiedTooltipTopLinkText":"Learn more","verifiedTooltipTopLinkVisible":true,"verifiedTooltipBottom":"","verifiedTooltipBottomLinkURL":"","verifiedTooltipBottomLinkText":"","verifiedTooltipBottomVisible":false,"verifiedTooltipBottomLinkVisible":false};
# root.RottenTomatoes.dtmData = {"webVersion":"node","clicktale":true,"rtVersion":3,"loggedInStatus":"","customerId":"","pageName":"rt | movies | reviews | Her","titleType":"Movie","titleId":"771356295","titleName":"Her","titleGenre":"Drama|Science Fiction & Fantasy|Special Interest|Romance","lifeCycleWindow":"[on-dvd]","emsID":"658731ff-1c7d-3c09-9339-887185615355"};
# root.RottenTomatoes.context.reviewConfig = {"linkOnly":false,"posterImage":{"height":270,"width":180},"reviewer":{"defaultImageUrl":"https:\u002F\u002Fwww.rottentomatoes.com\u002Fstatic\u002Fimages\u002Fredesign\u002Factor.default.tmb.gif","image":{"height":120,"width":100}},"trailersGallery":{"image":{"height":53,"width":80},"defaultImageUrl":"https:\u002F\u002Fstaticv2-4.rottentomatoes.com\u002Fstatic\u002Fimages\u002Fdefaults\u002Fvideo.default.l.jpg","showTrailers":true}};
# }(this));
# </script>
#
#         <script src="/assets/pizza-pie/javascripts/bundles/vendor.6c026c4ea5b.js"></script>
#
#         <script src="/assets/pizza-pie/javascripts/bundles/client-side-templates.49aed1d3c4a.js"></script>
#
#         <script src="/assets/pizza-pie/javascripts/bundles/global.b78e7e6cf05.js"></script>
#
#         <script src="https://cdn.jsdelivr.net/npm/algoliasearch@4/dist/algoliasearch-lite.umd.js"></script>
#         <script src="/assets/pizza-pie/javascripts/bundles/search-algolia.a6aa97fd89d.js"></script>
#
#
#             <script src="/assets/pizza-pie/javascripts/bundles/blueKai.93fda013f61.js"></script>
#
#
#
#             <script src="/assets/pizza-pie/javascripts/bundles/chartbeat.692f1df566a.js"></script>
#
#
#
#     <script src="/assets/pizza-pie/javascripts/templates/movie-reviews.6bcef226c30.js"></script>
#
#     <script src="/assets/pizza-pie/javascripts/bundles/movie-reviews.d6cd8baa66e.js"></script>
#
#
#
#             <script>
#             if ('function' === typeof window.mps.writeFooter) window.mps.writeFooter()
#             </script>
#
#
#
#     <script type="text/javascript">var _cf = _cf || []; _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/assets/8c2eb5a1ui234770e5a42e3396b435']); </script><script src="/assets/8c2eb5a1ui234770e5a42e3396b435" type="text/javascript"></script>
#
# </body></html>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3>The attribute scraping can be done in several ways.</h3>
#     <h3>The attributes <kbd>class</kbd> and <kbd>id</kbd> are scraped slightly differently.</h3>
#     <h3>CSS selectors can also be used to select html elements in more varied ways.</h3><br>
#     <img src="attrs.jpg">
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>From the Her reviews' page, we'll scrape 4 pieces of data to form our data set.</h3><br>
# <img src="her.jpg">
# </div>

# %%
# From the parsed HTML document stored in the htmlDoc variable above extract all the element that contain
# the names of the critics on the page
# To avoid grabbing all other content marked up with <a> elements on this page, we need to target only those <a>s
# that contain only the names of the critics
# This is why we need to pass the class attributes with their values as arguments to the .find_all() method

critic_Names = htmlDoc.find_all('a', class_='unstyled bold articleLink')

critic_Names

# Alternatively, you may select this content as .find_all('a', attrs={'class':'unstyled bold articleLink'}).
# This is a more explicit way that uses the argument attrs and the dictionary format.
# Out:
# [<a class="unstyled bold articleLink" href="/critic/mike-massie">Mike Massie</a>,
#  <a class="unstyled bold articleLink" href="/critic/film-companion-staff">Film Companion Staff</a>,
#  <a class="unstyled bold articleLink" href="/critic/richard-propes-27470">Richard Propes</a>,
#  <a class="unstyled bold articleLink" href="/critic/brent-mcknight">Brent McKnight</a>,
#  <a class="unstyled bold articleLink" href="/critic/damond-fudge">Damond Fudge</a>,
#  <a class="unstyled bold articleLink" href="/critic/yasser-medina">Yasser Medina</a>,
#  <a class="unstyled bold articleLink" href="/critic/jim-ross">Jim Ross</a>,
#  <a class="unstyled bold articleLink" href="/critic/david-harris">David Harris</a>,
#  <a class="unstyled bold articleLink" href="/critic/katie-smith-wong">Katie Smith-Wong</a>,
#  <a class="unstyled bold articleLink" href="/critic/ryan-syrek">Ryan Syrek</a>,
#  <a class="unstyled bold articleLink" href="/critic/matthew-lucas">Matthew Lucas</a>,
#  <a class="unstyled bold articleLink" href="/critic/cj-prince">C.J. Prince</a>,
#  <a class="unstyled bold articleLink" href="/critic/tom-bond">Tom Bond</a>,
#  <a class="unstyled bold articleLink" href="/critic/nicolas-ruiz">Nicolás Ruiz</a>,
#  <a class="unstyled bold articleLink" href="/critic/ruth-maramis">Ruth Maramis</a>,
#  <a class="unstyled bold articleLink" href="/critic/daniel-green">Daniel Green</a>,
#  <a class="unstyled bold articleLink" href="/critic/micheal-compton">Micheal Compton</a>,
#  <a class="unstyled bold articleLink" href="/critic/amanda-greever">Amanda Greever</a>,
#  <a class="unstyled bold articleLink" href="/critic/nathalia-aryani">Nathalia Aryani</a>,
#  <a class="unstyled bold articleLink" href="/critic/tara-thorne">Tara Thorne</a>]

# %%
# Let's iterate through the entire list of critics' names to extract content only and leave out html tags.
# Iterate through the list we've created above to extract only the text and leave out the HTML tags.
# Your loop should append the extracted text to the Names variable.

Names = []

for i in critic_Names:
    name = i.text
    Names.append(name)

Names
# Out:
# ['Mike Massie',
#  'Film Companion Staff',
#  'Richard Propes',
#  'Brent McKnight',
#  'Damond Fudge',
#  'Yasser Medina',
#  'Jim Ross',
#  'David Harris',
#  'Katie Smith-Wong',
#  'Ryan Syrek',
#  'Matthew Lucas',
#  'C.J. Prince',
#  'Tom Bond',
#  'Nicolás Ruiz',
#  'Ruth Maramis',
#  'Daniel Green',
#  'Micheal Compton',
#  'Amanda Greever',
#  'Nathalia Aryani',
#  'Tara Thorne']

# %%
# Scrape all the names of media that the critics represent.

critic_Sources = htmlDoc.find_all('em', class_='subtle')

critic_Sources
# Out:
# [<em class="subtle critic-publication">Gone With The Twins</em>,
#  <em class="subtle critic-publication">Film Companion</em>,
#  <em class="subtle critic-publication">TheIndependentCritic.com</em>,
#  <em class="subtle critic-publication">The Last Thing I See</em>,
#  <em class="subtle critic-publication">KCCI (Des Moines, IA)</em>,
#  <em class="subtle critic-publication">Cinemaficionados</em>,
#  <em class="subtle critic-publication">TAKE ONE Magazine</em>,
#  <em class="subtle critic-publication">Spectrum Culture</em>,
#  <em class="subtle critic-publication">Flick Feast</em>,
#  <em class="subtle critic-publication">The Reader (Omaha, NE)</em>,
#  <em class="subtle critic-publication">The Dispatch (Lexington, NC)</em>,
#  <em class="subtle critic-publication">Way Too Indie</em>,
#  <em class="subtle critic-publication">One Room With A View</em>,
#  <em class="subtle critic-publication">Código espagueti</em>,
#  <em class="subtle critic-publication">FlixChatter Film Blog</em>,
#  <em class="subtle critic-publication">CineVue</em>,
#  <em class="subtle critic-publication">Bowling Green Daily News</em>,
#  <em class="subtle critic-publication">The Daily Times (Tennessee)</em>,
#  <em class="subtle critic-publication">San Diego Entertainer</em>,
#  <em class="subtle critic-publication">The Coast (Halifax, Nova Scotia)</em>]

# %%
# Now iterate through the list of the extracted HTML content that contains info on media to extract text only.
# Store eveything in the Media variable.

Media = []

for i in critic_Sources:
    text = i.text
    Media.append(text)
    
Media
# Out:
# ['Gone With The Twins',
#  'Film Companion',
#  'TheIndependentCritic.com',
#  'The Last Thing I See',
#  'KCCI (Des Moines, IA)',
#  'Cinemaficionados',
#  'TAKE ONE Magazine',
#  'Spectrum Culture',
#  'Flick Feast',
#  'The Reader (Omaha, NE)',
#  'The Dispatch (Lexington, NC)',
#  'Way Too Indie',
#  'One Room With A View',
#  'Código espagueti',
#  'FlixChatter Film Blog',
#  'CineVue',
#  'Bowling Green Daily News',
#  'The Daily Times (Tennessee)',
#  'San Diego Entertainer',
#  'The Coast (Halifax, Nova Scotia)']

# %%
# Extract the HTML parts that contain all the scores that critics gave to rate the movies.
# Again, we need to target only those <div>s that have the class attrobute of a certain value;
# otherwise, we scrape all irrelevant content that might be marked up with <div>s

# Pay attention that you'll have to strip off the text that says 'Original Score:' at some point.

critic_Scores = htmlDoc.find_all('div', class_='small subtle review-link')

critic_Scores
# Out:
# [<div class="small subtle review-link">
#
#
#
#
#
#                          <a href="http://gonewiththetwins.com/new/her-2013/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 3/10
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.filmcompanion.in/category/reviews/movies/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://theindependentcritic.com/her" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4.0/4.0
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.thelastthingisee.com/2013/12/her-movie-review.html" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: A
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.kcci.com/article/movie-review-her-wonderfully-examines-the-nature-of-love/6888082" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.cinemaficionados.com/2014/01/her-2013.html" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 8/10
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="http://takeonecinema.net/2014/her/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://spectrumculture.com/2014/01/09/her/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4.2/5
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.flickfeast.co.uk/feature/jonze-her-2013-5/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4.5/5
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://thereader.com/film/herreview" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: B+
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.the-dispatch.com/lifestyle/20140115/her-delivers-a-remarkable-love-story-for-our-time" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 3.5/4
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="http://waytooindie.com/features/way-indies-favorite-movie-scenes-2013/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://oneroomwithaview.com/2014/02/14/her-review/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4/5
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://codigoespagueti.com/resenas/her/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 9/10
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://flixchatter.net/2014/01/10/flixchatter-review-spike-jonzes-her/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4.5/5
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://cine-vue.com/2014/02/film-review-her.html" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: 4/5
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.bgdailynews.com/community/intense-lone-survivor-showcases-brutality-of-battle/article_965c2b9e-8cae-5ed6-a4fb-7f66e1a4fc74.html" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                           | Original Score: B+
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.thedailytimes.com/entertainment/review-her-offers-a-beautiful-love-story-with-disturbing-commentary/article_17cd56e5-4406-55f1-8382-27f20128cadc.html" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.sdentertainer.com/movies/movie-review-her/" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>, <div class="small subtle review-link">
#
#
#
#
#
#                          <a href="https://www.thecoast.ca/halifax/her/Content?oid=4181001" nofollow="" target='"_blank"'>Full Review</a>
#
#
#
#                  </div>]

# %%
# Iterate through the list of scores to extract and store scores in the Scores variable. 

# When looping, slice off the part of strings in the list that contains the scores only as below.
# There are other ways to extract score only, e.g. by writing a Regex that matches only score digits and letters
# Otherwise, the output will contain scores and strings 'Original Score:', 'Full Review', and the vertical bar | 
# HINT --> alternatively, you may use replace() to replace unwanted items in a string with whitespaces.

import re # import the regular expression module

Scores = []

for i in critic_Scores:
    text2 = i.text[236:259]
    Reg = re.sub(r"Original Score: ", "", text2) # here use the .sub() method of re to get rid of the wording
    Scores.append(Reg)

# Alternatively, in the loop, write a Regex with the re method .findall(r"") to match only digit and letter scores

Scores
# Out:
# ['3/10\n  ',
#  '',
#  '4.0/4.0',
#  'A\n     ',
#  '',
#  '8/10\n  ',
#  '',
#  '4.2/5\n ',
#  '4.5/5\n ',
#  'B+\n    ',
#  '3.5/4\n ',
#  '',
#  '4/5\n   ',
#  '9/10\n  ',
#  '4.5/5\n ',
#  '4/5\n   ',
#  'B+\n    ',
#  '',
#  '',
#  '']

# %%
# Extract the HTML part that contains the content of review text.

critic_Reviews = htmlDoc.find_all('div', class_='the_review')

critic_Reviews
# Out:
# [<div class="the_review">
#                      Had Samantha taken a downward spiraling turn toward the HAL 9000 spectrum of robots, this movie could have been exciting.
#                  </div>, <div class="the_review">
#                      Tender, soulful, and thought provoking, Spike Jonze's film uses its bizarre sci-fi scenario to both comment on the modern reliance on technology as well as impart wisdom about the state of human relationships.
#                  </div>, <div class="the_review">
#                      I wasn't blown away by Her. I was enveloped by it.
#                  </div>, <div class="the_review">
#                      A sweet, delicate story, that can be emotionally pummeling while never losing its fundamental optimism.
#                  </div>, <div class="the_review">
#                      An unconventional way of telling an age-old story that works so well that you forget about its unconventionality as its humanity washes over you.
#                  </div>, <div class="the_review">
#                      It is a romantic drama bordering on the eccentric and is not afraid to show the psychological depth of human relationships. [Full review in Spanish]
#                  </div>, <div class="the_review">
#                      ...the film excels in its terrific execution and intriguing framework; and despite the technological trappings and high concept, HER is filled with humanity.
#                  </div>, <div class="the_review">
#                      Her has the most richly genuine denouement, a sincere sense of awakening where a stunted character recognizes his potential.
#                  </div>, <div class="the_review">
#                      Overall, Her is a beautiful film - wonderful acting, great story and dreamy soundtrack. Miss it and you'll miss out.
#                  </div>, <div class="the_review">
#                      Her wasn't as fantastically profound emotionally as the similarly toned Eternal Sunshine of the Spotless Mind. It lopes a bit in the middle when you want it to run.
#                  </div>, <div class="the_review">
#                      One of the most deeply felt and profoundly wise love stories to come along in a long time.
#                  </div>, <div class="the_review">
#                      The story of a man falling in love with his computer is an absurd sitcom-ready premise, but through Spike Jonze's vision it's looked at in a disarming and surprisingly sincere light.
#                  </div>, <div class="the_review">
#                      The first rush of new love feels as real and euphoric as any traditional relationship and slowly sours into disaffection and jealousy with just as much familiarity.
#                  </div>, <div class="the_review">
#                      Her is an intelligent and beautiful achievement in science fictional romance; a film about human fragility and the strangest aspirations of platonic love. [Full review in Spanish]
#                  </div>, <div class="the_review">
#                      There are so many rich nuances in this film that I could mull over and contemplate with, it's definitely one of those films that I'd like to watch more than once just to absorb it all again.
#                  </div>, <div class="the_review">
#                      Beginning life as a quirky rom-com before turning into something far greater and more profound, Jonze's Her puts forward a convincing and compelling defense of technology's growing dominion over our everyday lives.
#                  </div>, <div class="the_review">
#                      A bizarre little concoction that proves to be rather sweet and charming.
#                  </div>, <div class="the_review">
#                      The film isn't for everyone... But it offers a beautiful and savvy look at relationships worth checking out.
#                  </div>, <div class="the_review">
#                      Bizarre and the beautiful, it works.
#                  </div>, <div class="the_review">
#                      Her is essentially a one-hander (because Samantha has no hands) about love and relationships and what it all means. Which is fine, because even the Jonze films that miss (Where the Wild Things Are) are still nice to watch.
#                  </div>]

# %%
# Extract the text only and store in the variable called 'Reviews'.

Reviews = []

for i in critic_Reviews:
    text3 = i.text
    Reviews.append(text3)
    
Reviews
# Out:
# ['\n                    Had Samantha taken a downward spiraling turn toward the HAL 9000 spectrum of robots, this movie could have been exciting.\n                ',
#  "\n                    Tender, soulful, and thought provoking, Spike Jonze's film uses its bizarre sci-fi scenario to both comment on the modern reliance on technology as well as impart wisdom about the state of human relationships.\n                ",
#  "\n                    I wasn't blown away by Her. I was enveloped by it.\n                ",
#  '\n                    A sweet, delicate story, that can be emotionally pummeling while never losing its fundamental optimism.\n                ',
#  '\n                    An unconventional way of telling an age-old story that works so well that you forget about its unconventionality as its humanity washes over you.\n                ',
#  '\n                    It is a romantic drama bordering on the eccentric and is not afraid to show the psychological depth of human relationships. [Full review in Spanish]\n                ',
#  '\n                    ...the film excels in its terrific execution and intriguing framework; and despite the technological trappings and high concept, HER is filled with humanity.\n                ',
#  '\n                    Her has the most richly genuine denouement, a sincere sense of awakening where a stunted character recognizes his potential.\n                ',
#  "\n                    Overall, Her is a beautiful film - wonderful acting, great story and dreamy soundtrack. Miss it and you'll miss out.\n                ",
#  "\n                    Her wasn't as fantastically profound emotionally as the similarly toned Eternal Sunshine of the Spotless Mind. It lopes a bit in the middle when you want it to run.\n                ",
#  '\n                    One of the most deeply felt and profoundly wise love stories to come along in a long time.\n                ',
#  "\n                    The story of a man falling in love with his computer is an absurd sitcom-ready premise, but through Spike Jonze's vision it's looked at in a disarming and surprisingly sincere light.\n                ",
#  '\n                    The first rush of new love feels as real and euphoric as any traditional relationship and slowly sours into disaffection and jealousy with just as much familiarity.\n                ',
#  '\n                    Her is an intelligent and beautiful achievement in science fictional romance; a film about human fragility and the strangest aspirations of platonic love. [Full review in Spanish]\n                ',
#  "\n                    There are so many rich nuances in this film that I could mull over and contemplate with, it's definitely one of those films that I'd like to watch more than once just to absorb it all again.\n                ",
#  "\n                    Beginning life as a quirky rom-com before turning into something far greater and more profound, Jonze's Her puts forward a convincing and compelling defense of technology's growing dominion over our everyday lives.\n                ",
#  '\n                    A bizarre little concoction that proves to be rather sweet and charming.\n                ',
#  "\n                    The film isn't for everyone... But it offers a beautiful and savvy look at relationships worth checking out.\n                ",
#  '\n                    Bizarre and the beautiful, it works.\n                ',
#  '\n                    Her is essentially a one-hander (because Samantha has no hands) about love and relationships and what it all means. Which is fine, because even the Jonze films that miss (Where the Wild Things Are) are still nice to watch.\n                ']

# %%
# Replace empty strings in the Score list with None values by writing a conditional statement inside
# a list comprehension construct.
# Alternatively, you may write a for-loop with an if-condition

Scores = [None if x == '' else x for x in Scores]

Scores
# Out:
# ['3/10\n  ',
#  None,
#  '4.0/4.0',
#  'A\n     ',
#  None,
#  '8/10\n  ',
#  None,
#  '4.2/5\n ',
#  '4.5/5\n ',
#  'B+\n    ',
#  '3.5/4\n ',
#  None,
#  '4/5\n   ',
#  '9/10\n  ',
#  '4.5/5\n ',
#  '4/5\n   ',
#  'B+\n    ',
#  None,
#  None,
#  None]

# %%
# Load pandas to put up 4 lists of scraped data as columns in pandas' DataFrame.

import pandas as pd

myList = [Names, Media, Scores, Reviews]

myList
# We've create a multidimensional list
# Out:
# [['Mike Massie',
#   'Film Companion Staff',
#   'Richard Propes',
#   'Brent McKnight',
#   'Damond Fudge',
#   'Yasser Medina',
#   'Jim Ross',
#   'David Harris',
#   'Katie Smith-Wong',
#   'Ryan Syrek',
#   'Matthew Lucas',
#   'C.J. Prince',
#   'Tom Bond',
#   'Nicolás Ruiz',
#   'Ruth Maramis',
#   'Daniel Green',
#   'Micheal Compton',
#   'Amanda Greever',
#   'Nathalia Aryani',
#   'Tara Thorne'],
#  ['Gone With The Twins',
#   'Film Companion',
#   'TheIndependentCritic.com',
#   'The Last Thing I See',
#   'KCCI (Des Moines, IA)',
#   'Cinemaficionados',
#   'TAKE ONE Magazine',
#   'Spectrum Culture',
#   'Flick Feast',
#   'The Reader (Omaha, NE)',
#   'The Dispatch (Lexington, NC)',
#   'Way Too Indie',
#   'One Room With A View',
#   'Código espagueti',
#   'FlixChatter Film Blog',
#   'CineVue',
#   'Bowling Green Daily News',
#   'The Daily Times (Tennessee)',
#   'San Diego Entertainer',
#   'The Coast (Halifax, Nova Scotia)'],
#  ['3/10\n  ',
#   None,
#   '4.0/4.0',
#   'A\n     ',
#   None,
#   '8/10\n  ',
#   None,
#   '4.2/5\n ',
#   '4.5/5\n ',
#   'B+\n    ',
#   '3.5/4\n ',
#   None,
#   '4/5\n   ',
#   '9/10\n  ',
#   '4.5/5\n ',
#   '4/5\n   ',
#   'B+\n    ',
#   None,
#   None,
#   None],
#  ['\n                    Had Samantha taken a downward spiraling turn toward the HAL 9000 spectrum of robots, this movie could have been exciting.\n                ',
#   "\n                    Tender, soulful, and thought provoking, Spike Jonze's film uses its bizarre sci-fi scenario to both comment on the modern reliance on technology as well as impart wisdom about the state of human relationships.\n                ",
#   "\n                    I wasn't blown away by Her. I was enveloped by it.\n                ",
#   '\n                    A sweet, delicate story, that can be emotionally pummeling while never losing its fundamental optimism.\n                ',
#   '\n                    An unconventional way of telling an age-old story that works so well that you forget about its unconventionality as its humanity washes over you.\n                ',
#   '\n                    It is a romantic drama bordering on the eccentric and is not afraid to show the psychological depth of human relationships. [Full review in Spanish]\n                ',
#   '\n                    ...the film excels in its terrific execution and intriguing framework; and despite the technological trappings and high concept, HER is filled with humanity.\n                ',
#   '\n                    Her has the most richly genuine denouement, a sincere sense of awakening where a stunted character recognizes his potential.\n                ',
#   "\n                    Overall, Her is a beautiful film - wonderful acting, great story and dreamy soundtrack. Miss it and you'll miss out.\n                ",
#   "\n                    Her wasn't as fantastically profound emotionally as the similarly toned Eternal Sunshine of the Spotless Mind. It lopes a bit in the middle when you want it to run.\n                ",
#   '\n                    One of the most deeply felt and profoundly wise love stories to come along in a long time.\n                ',
#   "\n                    The story of a man falling in love with his computer is an absurd sitcom-ready premise, but through Spike Jonze's vision it's looked at in a disarming and surprisingly sincere light.\n                ",
#   '\n                    The first rush of new love feels as real and euphoric as any traditional relationship and slowly sours into disaffection and jealousy with just as much familiarity.\n                ',
#   '\n                    Her is an intelligent and beautiful achievement in science fictional romance; a film about human fragility and the strangest aspirations of platonic love. [Full review in Spanish]\n                ',
#   "\n                    There are so many rich nuances in this film that I could mull over and contemplate with, it's definitely one of those films that I'd like to watch more than once just to absorb it all again.\n                ",
#   "\n                    Beginning life as a quirky rom-com before turning into something far greater and more profound, Jonze's Her puts forward a convincing and compelling defense of technology's growing dominion over our everyday lives.\n                ",
#   '\n                    A bizarre little concoction that proves to be rather sweet and charming.\n                ',
#   "\n                    The film isn't for everyone... But it offers a beautiful and savvy look at relationships worth checking out.\n                ",
#   '\n                    Bizarre and the beautiful, it works.\n                ',
#   '\n                    Her is essentially a one-hander (because Samantha has no hands) about love and relationships and what it all means. Which is fine, because even the Jonze films that miss (Where the Wild Things Are) are still nice to watch.\n                ']]

# %%
# We may use the pandas' method .concat()
# In the webinar of Week 8, we used list(zip()) functions to combine 4 separate lists instead.

# Pass a list comprehension construct to the pandas' .concat() method 
# Inside the list comprehension construct, we convert each nested list in myList into a pd.Series()
# Once the conversion is done, 4 pandas Series will be put together by the .concat() method into a DataFrame


herDF = pd.concat([pd.Series(x) for x in myList], axis=1)

herDF

# Alternatively, you can use a dict format to put lists together and convert them to a pd DataFrame, e.g.
# herDF = pd.DataFrame({'Name':Names, 'Source': Media, 'Score': Scores, 'Review': Reviews})

# The dict keys are column names, and the dict values are the names of lists we created earlier
# Out:
#                        0                                 1         2  \
# 0            Mike Massie               Gone With The Twins  3/10\n
# 1   Film Companion Staff                    Film Companion      None
# 2         Richard Propes          TheIndependentCritic.com   4.0/4.0
# 3         Brent McKnight              The Last Thing I See  A\n
# 4           Damond Fudge             KCCI (Des Moines, IA)      None
# 5          Yasser Medina                  Cinemaficionados  8/10\n
# 6               Jim Ross                 TAKE ONE Magazine      None
# 7           David Harris                  Spectrum Culture  4.2/5\n
# 8       Katie Smith-Wong                       Flick Feast  4.5/5\n
# 9             Ryan Syrek            The Reader (Omaha, NE)  B+\n
# 10         Matthew Lucas      The Dispatch (Lexington, NC)  3.5/4\n
# 11           C.J. Prince                     Way Too Indie      None
# 12              Tom Bond              One Room With A View  4/5\n
# 13          Nicolás Ruiz                  Código espagueti  9/10\n
# 14          Ruth Maramis             FlixChatter Film Blog  4.5/5\n
# 15          Daniel Green                           CineVue  4/5\n
# 16       Micheal Compton          Bowling Green Daily News  B+\n
# 17        Amanda Greever       The Daily Times (Tennessee)      None
# 18       Nathalia Aryani             San Diego Entertainer      None
# 19           Tara Thorne  The Coast (Halifax, Nova Scotia)      None
#
#                                                     3
# 0   \n                    Had Samantha taken a dow...
# 1   \n                    Tender, soulful, and tho...
# 2   \n                    I wasn't blown away by H...
# 3   \n                    A sweet, delicate story,...
# 4   \n                    An unconventional way of...
# 5   \n                    It is a romantic drama b...
# 6   \n                    ...the film excels in it...
# 7   \n                    Her has the most richly ...
# 8   \n                    Overall, Her is a beauti...
# 9   \n                    Her wasn't as fantastica...
# 10  \n                    One of the most deeply f...
# 11  \n                    The story of a man falli...
# 12  \n                    The first rush of new lo...
# 13  \n                    Her is an intelligent an...
# 14  \n                    There are so many rich n...
# 15  \n                    Beginning life as a quir...
# 16  \n                    A bizarre little concoct...
# 17  \n                    The film isn't for every...
# 18  \n                    Bizarre and the beautifu...
# 19  \n                    Her is essentially a one...

# %%
# With the pandas .columns property, rename the columns which are now named by index position. 

herDF.columns=['Name', 'Source', 'Score', 'Review']

herDF

# Next delete the rows that have missing values in the Score column if you intend to work with score variables
# Yet if you intend to apply text analytics to Reviews data, you might leave those rows, just remove \n character
# Out:
#                     Name                            Source     Score  \
# 0            Mike Massie               Gone With The Twins  3/10\n
# 1   Film Companion Staff                    Film Companion      None
# 2         Richard Propes          TheIndependentCritic.com   4.0/4.0
# 3         Brent McKnight              The Last Thing I See  A\n
# 4           Damond Fudge             KCCI (Des Moines, IA)      None
# 5          Yasser Medina                  Cinemaficionados  8/10\n
# 6               Jim Ross                 TAKE ONE Magazine      None
# 7           David Harris                  Spectrum Culture  4.2/5\n
# 8       Katie Smith-Wong                       Flick Feast  4.5/5\n
# 9             Ryan Syrek            The Reader (Omaha, NE)  B+\n
# 10         Matthew Lucas      The Dispatch (Lexington, NC)  3.5/4\n
# 11           C.J. Prince                     Way Too Indie      None
# 12              Tom Bond              One Room With A View  4/5\n
# 13          Nicolás Ruiz                  Código espagueti  9/10\n
# 14          Ruth Maramis             FlixChatter Film Blog  4.5/5\n
# 15          Daniel Green                           CineVue  4/5\n
# 16       Micheal Compton          Bowling Green Daily News  B+\n
# 17        Amanda Greever       The Daily Times (Tennessee)      None
# 18       Nathalia Aryani             San Diego Entertainer      None
# 19           Tara Thorne  The Coast (Halifax, Nova Scotia)      None
#
#                                                Review
# 0   \n                    Had Samantha taken a dow...
# 1   \n                    Tender, soulful, and tho...
# 2   \n                    I wasn't blown away by H...
# 3   \n                    A sweet, delicate story,...
# 4   \n                    An unconventional way of...
# 5   \n                    It is a romantic drama b...
# 6   \n                    ...the film excels in it...
# 7   \n                    Her has the most richly ...
# 8   \n                    Overall, Her is a beauti...
# 9   \n                    Her wasn't as fantastica...
# 10  \n                    One of the most deeply f...
# 11  \n                    The story of a man falli...
# 12  \n                    The first rush of new lo...
# 13  \n                    Her is an intelligent an...
# 14  \n                    There are so many rich n...
# 15  \n                    Beginning life as a quir...
# 16  \n                    A bizarre little concoct...
# 17  \n                    The film isn't for every...
# 18  \n                    Bizarre and the beautifu...
# 19  \n                    Her is essentially a one...

# %%
# Use the pandas' .dropna() method to remove the rows if any cell contains 'None' values

herDF2 = herDF.dropna()

herDF2.reset_index(drop=True) # you should get 13 rows instead of 20 in the end

# As for the inconsistent & mixed data types where scores are either letters or numbers, you'll need to decide 
# how to make the scores uniform either at this stage or earlier
# If not, you won't be able to map or otherwise visualize the distribution of data in this column
# Also make sure to get rid of the newline character in columns 'Score' and 'Review'
# Out:
#                 Name                        Source     Score  \
# 0        Mike Massie           Gone With The Twins  3/10\n
# 1     Richard Propes      TheIndependentCritic.com   4.0/4.0
# 2     Brent McKnight          The Last Thing I See  A\n
# 3      Yasser Medina              Cinemaficionados  8/10\n
# 4       David Harris              Spectrum Culture  4.2/5\n
# 5   Katie Smith-Wong                   Flick Feast  4.5/5\n
# 6         Ryan Syrek        The Reader (Omaha, NE)  B+\n
# 7      Matthew Lucas  The Dispatch (Lexington, NC)  3.5/4\n
# 8           Tom Bond          One Room With A View  4/5\n
# 9       Nicolás Ruiz              Código espagueti  9/10\n
# 10      Ruth Maramis         FlixChatter Film Blog  4.5/5\n
# 11      Daniel Green                       CineVue  4/5\n
# 12   Micheal Compton      Bowling Green Daily News  B+\n
#
#                                                Review
# 0   \n                    Had Samantha taken a dow...
# 1   \n                    I wasn't blown away by H...
# 2   \n                    A sweet, delicate story,...
# 3   \n                    It is a romantic drama b...
# 4   \n                    Her has the most richly ...
# 5   \n                    Overall, Her is a beauti...
# 6   \n                    Her wasn't as fantastica...
# 7   \n                    One of the most deeply f...
# 8   \n                    The first rush of new lo...
# 9   \n                    Her is an intelligent an...
# 10  \n                    There are so many rich n...
# 11  \n                    Beginning life as a quir...
# 12  \n                    A bizarre little concoct...
