# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>Week 10_Part 2. Mining Twitter via APIs</h2><br>
#     <p>Social media provide access to their data via APIs (Application Programming Interfaces) without giving access to their code. Read more on APIs <a href="https://bit.ly/2BuaAZN">here</a>.</p><br>
#     <p>To harvest Twitter data, you need to get API access by creating your Twitter User and Developer accounts. Once API access is granted, you can move on to create an app for a specific data mining purpose.</p><br>
#     <p>In this part, we'll harvest Twitter data by screen names and topics.</p>
# </div>

# %%
# We'll need to load the libraries of twython (an alternative one is tweepy) and time 
# to your coding environment.

# But first install twython on your computer via Windows cmd, Terminal or Anaconda Prompt.

# %%
# Load twython to your working environment.

# The twython module will make authenticated calls to Twitter API.


from twython import Twython as tw


# Check twython documention here: https://media.readthedocs.org/pdf/twython/stable/twython.pdf

# %%
# On Twitter developers account, you should have also generated 4 credentials for your Twitter app:

# These should be combinations of numbers and letters for:
# 1) API key, 2) API secret key, 3) API token, and 4) API secret token.

# Open your Twitter dev account and go to the app you must have created beforehand.

# From there, one at a time copy and paste credentials to store them in 4 Python variables, as below.



myKey = 'your key'

mySecretKey = 'your secret key'

myToken = 'your token'

mySecretToken = 'your secret token'

# %%
# Combine all 4 variables with your credentials in one variable to create a twython instance 
# by passing those variables to the tw() function of twython.

myTwitter = tw(myKey, mySecretKey,myToken, mySecretToken)


# Get the data map of your Twitter object. 
# Twitter data is stored in a lightweight data-interchange format called JSON (JavaSCript Object Notation).

myTwitter.verify_credentials()

# %%
# Now you are ready to tweet from your Python environment. 
# Using update_status(status=''), tweet to your Twitter from this coding environment.

myTwitter.update_status(status="Checking out update_status() method in Python")
# Out:
# {'created_at': 'Thu Dec 10 22:37:17 +0000 2020',
#  'id': 1337164512735145984,
#  'id_str': '1337164512735145984',
#  'text': 'Checking out update_status() method in Python',
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="https://twitter.com/" rel="nofollow">BxTweets</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 796372627396980736,
#   'id_str': '796372627396980736',
#   'name': 'Gabriele',
#   'screen_name': 'gabrielemucho2',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 3,
#   'friends_count': 30,
#   'listed_count': 1,
#   'created_at': 'Wed Nov 09 15:23:25 +0000 2016',
#   'favourites_count': 2,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 25,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/796372627396980736/1478705910',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %% [markdown]
# <h3>Check the timeline of your Twitter user account and see whether your message has been posted there.</h3><br>
# <img src="FromPythonToTwitter.JPG">

# %%
# The basic method of twython to harvest Twitter data is search().

# The q argument specifies the parameters of your search.

# Set the q parameter to the screen name of Charles Michel, who is the current president of EU Council
# Set the q argument to his handle '@eucopresident' to search his timeline. 

# The count is the number of Tweet statuses you may set to get back. 
# 200 is the max at one time, though twitter API tends to limit it to 100 

# The argument include_rts is a logical indication whether to include retweets in search results.


DTTimeline = myTwitter.search(q = '@eucopresident', count = 200, include_rts=1)

DTTimeline
# Out:
# {'statuses': [{'created_at': 'Thu Dec 10 22:38:25 +0000 2020',
#    'id': 1337164794663723014,
#    'id_str': '1337164794663723014',
#    'text': 'RT @eucopresident: Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies. \n\nO…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MFF', 'indices': [31, 35]},
#      {'text': 'NGEU', 'indices': [57, 62]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3069261371,
#     'id_str': '3069261371',
#     'name': 'EU in Australia',
#     'screen_name': 'EUinAus',
#     'location': 'Canberra, Australia',
#     'description': 'We represent the European Union in Australia at all levels. We work with #EU Member State diplomatic missions in #CBR. Follow our Ambassador @MichaelPulchEU',
#     'url': 'https://t.co/K4TO1q5XVb',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/K4TO1q5XVb',
#         'expanded_url': 'http://eeas.europa.eu/australia',
#         'display_url': 'eeas.europa.eu/australia',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7022,
#     'friends_count': 6000,
#     'listed_count': 377,
#     'created_at': 'Wed Mar 04 05:12:57 +0000 2015',
#     'favourites_count': 44680,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 22888,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1054568580446998528/b1wLdFx7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1054568580446998528/b1wLdFx7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3069261371/1601258250',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 17:58:20 +0000 2020',
#     'id': 1337094311389913090,
#     'id_str': '1337094311389913090',
#     'text': 'Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies… https://t.co/EieIQtsx6u',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MFF', 'indices': [12, 16]},
#       {'text': 'NGEU', 'indices': [38, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/EieIQtsx6u',
#        'expanded_url': 'https://twitter.com/i/web/status/1337094311389913090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 196994616,
#      'id_str': '196994616',
#      'name': 'Charles Michel',
#      'screen_name': 'eucopresident',
#      'location': 'EU',
#      'description': 'Twitter channel of Charles Michel, President of the European Council. Managed by the media team @EUCouncil. Personal account: @CharlesMichel',
#      'url': 'https://t.co/IlXN6s5WIu',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/IlXN6s5WIu',
#          'expanded_url': 'http://european-council.europa.eu/en/european-council/president/',
#          'display_url': 'european-council.europa.eu/en/european-co…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1184585,
#      'friends_count': 417,
#      'listed_count': 8254,
#      'created_at': 'Thu Sep 30 12:07:59 +0000 2010',
#      'favourites_count': 175,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 6599,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '002395',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/196994616/1603972296',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 717,
#     'favorite_count': 1763,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 717,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Dec 10 22:37:08 +0000 2020',
#    'id': 1337164473128390662,
#    'id_str': '1337164473128390662',
#    'text': 'RT @eucopresident: Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies. \n\nO…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MFF', 'indices': [31, 35]},
#      {'text': 'NGEU', 'indices': [57, 62]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 322231309,
#     'id_str': '322231309',
#     'name': 'geo kalp',
#     'screen_name': 'geokalp',
#     'location': '',
#     'description': 'ΔΕΟΠΣ / MSc in Finance',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 406,
#     'friends_count': 1583,
#     'listed_count': 19,
#     'created_at': 'Wed Jun 22 21:01:09 +0000 2011',
#     'favourites_count': 112147,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29983,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'BADFCD',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1408464258/profile2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1408464258/profile2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/322231309/1361873251',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': 'F2E195',
#     'profile_sidebar_fill_color': 'FFF7CC',
#     'profile_text_color': '0C3E53',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 17:58:20 +0000 2020',
#     'id': 1337094311389913090,
#     'id_str': '1337094311389913090',
#     'text': 'Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies… https://t.co/EieIQtsx6u',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MFF', 'indices': [12, 16]},
#       {'text': 'NGEU', 'indices': [38, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/EieIQtsx6u',
#        'expanded_url': 'https://twitter.com/i/web/status/1337094311389913090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 196994616,
#      'id_str': '196994616',
#      'name': 'Charles Michel',
#      'screen_name': 'eucopresident',
#      'location': 'EU',
#      'description': 'Twitter channel of Charles Michel, President of the European Council. Managed by the media team @EUCouncil. Personal account: @CharlesMichel',
#      'url': 'https://t.co/IlXN6s5WIu',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/IlXN6s5WIu',
#          'expanded_url': 'http://european-council.europa.eu/en/european-council/president/',
#          'display_url': 'european-council.europa.eu/en/european-co…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1184585,
#      'friends_count': 417,
#      'listed_count': 8254,
#      'created_at': 'Thu Sep 30 12:07:59 +0000 2010',
#      'favourites_count': 175,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 6599,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '002395',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/196994616/1603972296',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 717,
#     'favorite_count': 1763,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 717,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Dec 10 22:36:59 +0000 2020',
#    'id': 1337164433882304514,
#    'id_str': '1337164433882304514',
#    'text': 'RT @tiger__wounded: The Iranian people will never forget that you supported the freedom-loving people. Or terrorists ?!\n\n#روح\u200cالله_زم\n#Dont…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'روح\u200cالله_زم',
#       'indices': [121, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tiger__wounded',
#       'name': 'JOKER',
#       'id': 1085157412749889536,
#       'id_str': '1085157412749889536',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1085157412749889536,
#     'id_str': '1085157412749889536',
#     'name': 'JOKER',
#     'screen_name': 'tiger__wounded',
#     'location': '',
#     'description': '\u200f\u200f\u200f\u200f\u200f\u200fمن از آن هایی که در باور خود همیشه حق دارند ؛ متنفرم !\n\n            با افتخار \u200e\u200e\u200e\u200e#براندازم',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2927,
#     'friends_count': 2912,
#     'listed_count': 1,
#     'created_at': 'Tue Jan 15 12:51:03 +0000 2019',
#     'favourites_count': 38576,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 22092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1183152012516560897/D9yd-IxK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183152012516560897/D9yd-IxK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1085157412749889536/1578946667',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Dec 08 19:07:18 +0000 2020',
#     'id': 1336386890736525314,
#     'id_str': '1336386890736525314',
#     'text': 'The Iranian people will never forget that you supported the freedom-loving people. Or terrorists ?!\n\n#روح\u200cالله_زم… https://t.co/5nEULFH6J9',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'روح\u200cالله_زم',
#        'indices': [101, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/5nEULFH6J9',
#        'expanded_url': 'https://twitter.com/i/web/status/1336386890736525314',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1336382678195720197,
#     'in_reply_to_status_id_str': '1336382678195720197',
#     'in_reply_to_user_id': 1085157412749889536,
#     'in_reply_to_user_id_str': '1085157412749889536',
#     'in_reply_to_screen_name': 'tiger__wounded',
#     'user': {'id': 1085157412749889536,
#      'id_str': '1085157412749889536',
#      'name': 'JOKER',
#      'screen_name': 'tiger__wounded',
#      'location': '',
#      'description': '\u200f\u200f\u200f\u200f\u200f\u200fمن از آن هایی که در باور خود همیشه حق دارند ؛ متنفرم !\n\n            با افتخار \u200e\u200e\u200e\u200e#براندازم',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2927,
#      'friends_count': 2912,
#      'listed_count': 1,
#      'created_at': 'Tue Jan 15 12:51:03 +0000 2019',
#      'favourites_count': 38576,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 22092,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1183152012516560897/D9yd-IxK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183152012516560897/D9yd-IxK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1085157412749889536/1578946667',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 53,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Dec 10 22:36:50 +0000 2020',
#    'id': 1337164398796922882,
#    'id_str': '1337164398796922882',
#    'text': '@AndrejPlenkovic @SablatnikUros @JJansaSDS @vonderleyen @eucopresident @EU2020DE Čestitam... Hitro okrevanje i Srečno u godinu 2021',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AndrejPlenkovic',
#       'name': 'Andrej Plenković',
#       'id': 2190798482,
#       'id_str': '2190798482',
#       'indices': [0, 16]},
#      {'screen_name': 'SablatnikUros',
#       'name': 'Uroš Sablatnik 🇸🇮 Q',
#       'id': 1154867381988134913,
#       'id_str': '1154867381988134913',
#       'indices': [17, 31]},
#      {'screen_name': 'JJansaSDS',
#       'name': 'Janez Janša',
#       'id': 258856900,
#       'id_str': '258856900',
#       'indices': [32, 42]},
#      {'screen_name': 'vonderleyen',
#       'name': 'Ursula von der Leyen',
#       'id': 1146329871418843136,
#       'id_str': '1146329871418843136',
#       'indices': [43, 55]},
#      {'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [56, 70]},
#      {'screen_name': 'EU2020DE',
#       'name': 'EU2020DE',
#       'id': 3063912809,
#       'id_str': '3063912809',
#       'indices': [71, 80]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1337108595771658241,
#    'in_reply_to_status_id_str': '1337108595771658241',
#    'in_reply_to_user_id': 2190798482,
#    'in_reply_to_user_id_str': '2190798482',
#    'in_reply_to_screen_name': 'AndrejPlenkovic',
#    'user': {'id': 1241146151258259462,
#     'id_str': '1241146151258259462',
#     'name': 'Matjaž Lesjak',
#     'screen_name': 'LesjakMatjaz',
#     'location': 'Republic of Slovenia',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 200,
#     'friends_count': 334,
#     'listed_count': 2,
#     'created_at': 'Fri Mar 20 23:34:52 +0000 2020',
#     'favourites_count': 1084,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1136,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1323289201853538307/MshUudol_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1323289201853538307/MshUudol_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Dec 10 22:36:48 +0000 2020',
#    'id': 1337164389363961856,
#    'id_str': '1337164389363961856',
#    'text': 'Uh oh. Mimo uspokajających zapewnień @eucopresident , wciąż nie ma porozumienia co do celów redukcji na 2030 r. https://t.co/ihKqF9I8VM',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [37, 51]}],
#     'urls': [{'url': 'https://t.co/ihKqF9I8VM',
#       'expanded_url': 'https://twitter.com/MehreenKhn/status/1337160747441217539',
#       'display_url': 'twitter.com/MehreenKhn/sta…',
#       'indices': [112, 135]}]},
#    'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1637572098,
#     'id_str': '1637572098',
#     'name': 'Paweł Wiejski',
#     'screen_name': 'PWiejski',
#     'location': '',
#     'description': 'All things Europe and climate. Ex-@PolitykaInsight. Will write for money, DMs open.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 674,
#     'friends_count': 704,
#     'listed_count': 6,
#     'created_at': 'Thu Aug 01 09:49:18 +0000 2013',
#     'favourites_count': 3249,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1090,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1247468597959688192/hNjc7dl4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247468597959688192/hNjc7dl4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1637572098/1586254666',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1337160747441217539,
#    'quoted_status_id_str': '1337160747441217539',
#    'quoted_status': {'created_at': 'Thu Dec 10 22:22:20 +0000 2020',
#     'id': 1337160747441217539,
#     'id_str': '1337160747441217539',
#     'text': 'This text is not a goer for 🇵🇱🇨🇿. Babis wabnts  explicit mention gas in conclusions  while Poland PM wants guarante… https://t.co/BRkQLe9oKP',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/BRkQLe9oKP',
#        'expanded_url': 'https://twitter.com/i/web/status/1337160747441217539',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'pl', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1337153300530155522,
#     'in_reply_to_status_id_str': '1337153300530155522',
#     'in_reply_to_user_id': 19744053,
#     'in_reply_to_user_id_str': '19744053',
#     'in_reply_to_screen_name': 'MehreenKhn',
#     'user': {'id': 19744053,
#      'id_str': '19744053',
#      'name': 'Mehreen',
#      'screen_name': 'MehreenKhn',
#      'location': 'Brussels',
#      'description': 'Brussels correspondent @ft - views are mine but we can share them.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 25644,
#      'friends_count': 999,
#      'listed_count': 717,
#      'created_at': 'Fri Jan 30 00:06:37 +0000 2009',
#      'favourites_count': 2623,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 22123,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FCEBB6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/892762434678730752/vHnApctU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/892762434678730752/vHnApctU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19744053/1530301645',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': 'F0A830',
#      'profile_sidebar_fill_color': '78C0A8',
#      'profile_text_color': '5E412F',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pl'},
#   {'created_at': 'Thu Dec 10 22:36:31 +0000 2020',
#    'id': 1337164316630372355,
#    'id_str': '1337164316630372355',
#    'text': 'RT @eucopresident: Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies. \n\nO…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MFF', 'indices': [31, 35]},
#      {'text': 'NGEU', 'indices': [57, 62]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 111698138,
#     'id_str': '111698138',
#     'name': 'Ana Alonso Blanco',
#     'screen_name': 'aniitaa90',
#     'location': 'Madrid (ESP) - León (ESP)',
#     'description': 'Watching the life from the bright side\n\nEconomist, music lover and +VAVEL coordinator at @vavelcom',
#     'url': 'https://t.co/aVWuqCQ63Y',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/aVWuqCQ63Y',
#         'expanded_url': 'https://www.vavel.com/es/author/amalonso90',
#         'display_url': 'vavel.com/es/author/amal…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 677,
#     'friends_count': 531,
#     'listed_count': 39,
#     'created_at': 'Fri Feb 05 21:23:52 +0000 2010',
#     'favourites_count': 1193,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29099,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/729820220819439616/7abDR__T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/729820220819439616/7abDR__T_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/111698138/1471145857',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 17:58:20 +0000 2020',
#     'id': 1337094311389913090,
#     'id_str': '1337094311389913090',
#     'text': 'Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies… https://t.co/EieIQtsx6u',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MFF', 'indices': [12, 16]},
#       {'text': 'NGEU', 'indices': [38, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/EieIQtsx6u',
#        'expanded_url': 'https://twitter.com/i/web/status/1337094311389913090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 196994616,
#      'id_str': '196994616',
#      'name': 'Charles Michel',
#      'screen_name': 'eucopresident',
#      'location': 'EU',
#      'description': 'Twitter channel of Charles Michel, President of the European Council. Managed by the media team @EUCouncil. Personal account: @CharlesMichel',
#      'url': 'https://t.co/IlXN6s5WIu',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/IlXN6s5WIu',
#          'expanded_url': 'http://european-council.europa.eu/en/european-council/president/',
#          'display_url': 'european-council.europa.eu/en/european-co…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1184585,
#      'friends_count': 417,
#      'listed_count': 8254,
#      'created_at': 'Thu Sep 30 12:07:59 +0000 2010',
#      'favourites_count': 175,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 6599,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '002395',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/196994616/1603972296',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 717,
#     'favorite_count': 1763,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 717,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Dec 10 22:35:31 +0000 2020',
#    'id': 1337164068302561284,
#    'id_str': '1337164068302561284',
#    'text': '@JosepBorrellF @vonderleyen @eucopresident \n\nHistory will judge you harshly. \n@GermanyDiplo @MaltainEU @spainmfa… https://t.co/y8BBUAUrTm',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JosepBorrellF',
#       'name': 'Josep Borrell Fontelles',
#       'id': 1003895325025865730,
#       'id_str': '1003895325025865730',
#       'indices': [0, 14]},
#      {'screen_name': 'vonderleyen',
#       'name': 'Ursula von der Leyen',
#       'id': 1146329871418843136,
#       'id_str': '1146329871418843136',
#       'indices': [15, 27]},
#      {'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [28, 42]},
#      {'screen_name': 'GermanyDiplo',
#       'name': 'GermanForeignOffice',
#       'id': 453030125,
#       'id_str': '453030125',
#       'indices': [78, 91]},
#      {'screen_name': 'MaltainEU',
#       'name': 'MaltaPermRep 🇲🇹 🇪🇺',
#       'id': 1685567720,
#       'id_str': '1685567720',
#       'indices': [92, 102]},
#      {'screen_name': 'SpainMFA',
#       'name': 'Spain MFA',
#       'id': 2775155944,
#       'id_str': '2775155944',
#       'indices': [103, 112]}],
#     'urls': [{'url': 'https://t.co/y8BBUAUrTm',
#       'expanded_url': 'https://twitter.com/i/web/status/1337164068302561284',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 1003895325025865730,
#    'in_reply_to_user_id_str': '1003895325025865730',
#    'in_reply_to_screen_name': 'JosepBorrellF',
#    'user': {'id': 2805723316,
#     'id_str': '2805723316',
#     'name': 'D Tsarouhtsis',
#     'screen_name': 'DTsarouhtsis',
#     'location': 'Free Union VA USA ',
#     'description': 'Chemist PhD, Quality & Regulatory Affairs Director Med Devices/Informatics, USA Immigrant, Amused w/ Classics, good food & great wines❤️Journey to my Ithika',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 296,
#     'friends_count': 2339,
#     'listed_count': 0,
#     'created_at': 'Sat Oct 04 16:39:29 +0000 2014',
#     'favourites_count': 4713,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 6640,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1187182247440453634/I3bl34_H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1187182247440453634/I3bl34_H_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2805723316/1594930673',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1337156056540123136,
#    'quoted_status_id_str': '1337156056540123136',
#    'quoted_status': {'created_at': 'Thu Dec 10 22:03:41 +0000 2020',
#     'id': 1337156056540123136,
#     'id_str': '1337156056540123136',
#     'text': "Well, that's it. https://t.co/VNBmoy9d0X https://t.co/gb1FvTOUsu",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/VNBmoy9d0X',
#        'expanded_url': 'https://twitter.com/Nikitas_i/status/1336793600923996160',
#        'display_url': 'twitter.com/Nikitas_i/stat…',
#        'indices': [17, 40]}],
#      'media': [{'id': 1337156017713504258,
#        'id_str': '1337156017713504258',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/Eo6IUEUW4AIG30-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Eo6IUEUW4AIG30-.jpg',
#        'url': 'https://t.co/gb1FvTOUsu',
#        'display_url': 'pic.twitter.com/gb1FvTOUsu',
#        'expanded_url': 'https://twitter.com/MarcoFlorianMED/status/1337156056540123136/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 677, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 384, 'resize': 'fit'},
#         'large': {'w': 1200, 'h': 677, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1337156017713504258,
#        'id_str': '1337156017713504258',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/Eo6IUEUW4AIG30-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Eo6IUEUW4AIG30-.jpg',
#        'url': 'https://t.co/gb1FvTOUsu',
#        'display_url': 'pic.twitter.com/gb1FvTOUsu',
#        'expanded_url': 'https://twitter.com/MarcoFlorianMED/status/1337156056540123136/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 677, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 384, 'resize': 'fit'},
#         'large': {'w': 1200, 'h': 677, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1276202697583181834,
#      'id_str': '1276202697583181834',
#      'name': 'MarcoFlorianMED',
#      'screen_name': 'MarcoFlorianMED',
#      'location': 'Thessaloniki ',
#      'description': 'An Italian In Greece. \n#StandWithArmeniaGreeceCyprus',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2859,
#      'friends_count': 1484,
#      'listed_count': 27,
#      'created_at': 'Thu Jun 25 17:17:04 +0000 2020',
#      'favourites_count': 10151,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 14068,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1285661435184414726/7KrSt3qR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285661435184414726/7KrSt3qR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276202697583181834/1606488602',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1336793600923996160,
#     'quoted_status_id_str': '1336793600923996160',
#     'retweet_count': 3,
#     'favorite_count': 22,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Dec 10 22:35:29 +0000 2020',
#    'id': 1337164057300914177,
#    'id_str': '1337164057300914177',
#    'text': 'RT @BarendLeyts: Meeting of #EUCO chaired by @eucopresident has started again with discussion on #MFF and the rule of law conditionality me…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'EUCO', 'indices': [28, 33]},
#      {'text': 'MFF', 'indices': [97, 101]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BarendLeyts',
#       'name': 'Barend Leyts',
#       'id': 387858235,
#       'id_str': '387858235',
#       'indices': [3, 15]},
#      {'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [45, 59]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1080460907652759552,
#     'id_str': '1080460907652759552',
#     'name': 'Princ Milan',
#     'screen_name': 'MilanPrinc',
#     'location': 'Kumasi',
#     'description': 'Music,soccer and listening to my pastor.\npolitical analyst',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 203,
#     'friends_count': 2845,
#     'listed_count': 0,
#     'created_at': 'Wed Jan 02 13:48:49 +0000 2019',
#     'favourites_count': 72715,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 74224,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1307785659554332675/UPBrm1X__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307785659554332675/UPBrm1X__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1080460907652759552/1579104561',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 17:36:49 +0000 2020',
#     'id': 1337088897088704516,
#     'id_str': '1337088897088704516',
#     'text': 'Meeting of #EUCO chaired by @eucopresident has started again with discussion on #MFF and the rule of law conditiona… https://t.co/6u4digbVLQ',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'EUCO', 'indices': [11, 16]},
#       {'text': 'MFF', 'indices': [80, 84]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'eucopresident',
#        'name': 'Charles Michel',
#        'id': 196994616,
#        'id_str': '196994616',
#        'indices': [28, 42]}],
#      'urls': [{'url': 'https://t.co/6u4digbVLQ',
#        'expanded_url': 'https://twitter.com/i/web/status/1337088897088704516',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 387858235,
#      'id_str': '387858235',
#      'name': 'Barend Leyts',
#      'screen_name': 'BarendLeyts',
#      'location': 'Brussel, België',
#      'description': 'Spokesman @eucopresident',
#      'url': 'https://t.co/OPaaVEUlzK',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/OPaaVEUlzK',
#          'expanded_url': 'https://www.consilium.europa.eu/en/european-council/president/',
#          'display_url': 'consilium.europa.eu/en/european-co…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
# ...
#          'expanded_url': 'http://www.gov.si',
#          'display_url': 'gov.si',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/ikzwuXidyM',
#          'expanded_url': 'https://apple.co/2YPyeLZ',
#          'display_url': 'apple.co/2YPyeLZ',
#          'indices': [101, 124]},
#         {'url': 'https://t.co/Dn7gbcQlIe',
#          'expanded_url': 'https://bit.ly/2Q0mWzE',
#          'display_url': 'bit.ly/2Q0mWzE',
#          'indices': [134, 157]}]}},
#      'protected': False,
#      'followers_count': 84338,
#      'friends_count': 9500,
#      'listed_count': 296,
#      'created_at': 'Fri Jun 12 08:33:30 +0000 2009',
#      'favourites_count': 367,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 38200,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/735779464781565956/Ukq3gkS6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735779464781565956/Ukq3gkS6_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46612022/1605718418',
#      'profile_link_color': '0049AC',
#      'profile_sidebar_border_color': 'B1B0B0',
#      'profile_sidebar_fill_color': 'CADEE5',
#      'profile_text_color': '626060',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 93,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'sl'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'sl'},
#   {'created_at': 'Thu Dec 10 21:47:02 +0000 2020',
#    'id': 1337151864773767174,
#    'id_str': '1337151864773767174',
#    'text': 'RT @vladaRS: Vrh 🇪🇺 EU dosegel kompromis, ki odpravlja blokado svežnja za okrevanje v vrednosti 1824 milijard evrov. @JJansaSDS @EmmanuelMa…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'vladaRS',
#       'name': 'Vlada Republike Slovenije',
#       'id': 46612022,
#       'id_str': '46612022',
#       'indices': [3, 11]},
#      {'screen_name': 'JJansaSDS',
#       'name': 'Janez Janša',
#       'id': 258856900,
#       'id_str': '258856900',
#       'indices': [117, 127]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'sl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 258856900,
#     'id_str': '258856900',
#     'name': 'Janez Janša',
#     'screen_name': 'JJansaSDS',
#     'location': 'Ljubljana',
#     'description': 'PM 2020 -, 2004-2008, 2012-2013, President of SDS and VP of CDI-IDC, MOD 1990-94 & 2000, P of the EUCO 2008 RTnotEndorsement https://t.co/LrR1KyvqIi',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/LrR1KyvqIi',
#         'expanded_url': 'http://instagram.com/JJansaSDS',
#         'display_url': 'instagram.com/JJansaSDS',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 77254,
#     'friends_count': 2969,
#     'listed_count': 316,
#     'created_at': 'Mon Feb 28 17:10:49 +0000 2011',
#     'favourites_count': 12549,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 111811,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFF04D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1240987929918541824/uLUKsN-S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1240987929918541824/uLUKsN-S_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/258856900/1584809360',
#     'profile_link_color': '0099CC',
#     'profile_sidebar_border_color': 'FFF8AD',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 19:44:42 +0000 2020',
#     'id': 1337121080687915016,
#     'id_str': '1337121080687915016',
#     'text': 'Vrh 🇪🇺 EU dosegel kompromis, ki odpravlja blokado svežnja za okrevanje v vrednosti 1824 milijard evrov. @JJansaSDS… https://t.co/he7CJXWatN',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'JJansaSDS',
#        'name': 'Janez Janša',
#        'id': 258856900,
#        'id_str': '258856900',
#        'indices': [104, 114]}],
#      'urls': [{'url': 'https://t.co/he7CJXWatN',
#        'expanded_url': 'https://twitter.com/i/web/status/1337121080687915016',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'sl', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 46612022,
#      'id_str': '46612022',
#      'name': 'Vlada Republike Slovenije',
#      'screen_name': 'vladaRS',
#      'location': 'Slovenija',
#      'description': 'Tvita Urad vlade za komuniciranje. | English account @govSlovenia ‼️APLIKACIJA 📱 #OstaniZdrav‼️\niOS: https://t.co/ikzwuXidyM Android: https://t.co/Dn7gbcQlIe',
#      'url': 'https://t.co/hKJhPw7kR2',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/hKJhPw7kR2',
#          'expanded_url': 'http://www.gov.si',
#          'display_url': 'gov.si',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/ikzwuXidyM',
#          'expanded_url': 'https://apple.co/2YPyeLZ',
#          'display_url': 'apple.co/2YPyeLZ',
#          'indices': [101, 124]},
#         {'url': 'https://t.co/Dn7gbcQlIe',
#          'expanded_url': 'https://bit.ly/2Q0mWzE',
#          'display_url': 'bit.ly/2Q0mWzE',
#          'indices': [134, 157]}]}},
#      'protected': False,
#      'followers_count': 84338,
#      'friends_count': 9500,
#      'listed_count': 296,
#      'created_at': 'Fri Jun 12 08:33:30 +0000 2009',
#      'favourites_count': 367,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 38200,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/735779464781565956/Ukq3gkS6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735779464781565956/Ukq3gkS6_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46612022/1605718418',
#      'profile_link_color': '0049AC',
#      'profile_sidebar_border_color': 'B1B0B0',
#      'profile_sidebar_fill_color': 'CADEE5',
#      'profile_text_color': '626060',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 93,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'sl'},
#    'is_quote_status': False,
#    'retweet_count': 23,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'sl'},
#   {'created_at': 'Thu Dec 10 21:46:02 +0000 2020',
#    'id': 1337151615128772609,
#    'id_str': '1337151615128772609',
#    'text': 'RT @eucopresident: Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies. \n\nO…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MFF', 'indices': [31, 35]},
#      {'text': 'NGEU', 'indices': [57, 62]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'eucopresident',
#       'name': 'Charles Michel',
#       'id': 196994616,
#       'id_str': '196994616',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 177523854,
#     'id_str': '177523854',
#     'name': 'Igor Arrieta',
#     'screen_name': 'Igor_Arrieta',
#     'location': 'Errenteria',
#     'description': 'PhD student in Mathematics @UnivDeCoimbra. MSc Pure Mathematics @Cambridge_Uni.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 85,
#     'friends_count': 457,
#     'listed_count': 1,
#     'created_at': 'Thu Aug 12 10:42:17 +0000 2010',
#     'favourites_count': 1852,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1678,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1150132766153089025/5B3Z2nBM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1150132766153089025/5B3Z2nBM_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/177523854/1543189435',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 17:58:20 +0000 2020',
#     'id': 1337094311389913090,
#     'id_str': '1337094311389913090',
#     'text': 'Deal on the #MFF and Recovery Package #NGEU \n\nNow we can start with the implementation and build back our economies… https://t.co/EieIQtsx6u',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MFF', 'indices': [12, 16]},
#       {'text': 'NGEU', 'indices': [38, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/EieIQtsx6u',
#        'expanded_url': 'https://twitter.com/i/web/status/1337094311389913090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 196994616,
#      'id_str': '196994616',
#      'name': 'Charles Michel',
#      'screen_name': 'eucopresident',
#      'location': 'EU',
#      'description': 'Twitter channel of Charles Michel, President of the European Council. Managed by the media team @EUCouncil. Personal account: @CharlesMichel',
#      'url': 'https://t.co/IlXN6s5WIu',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/IlXN6s5WIu',
#          'expanded_url': 'http://european-council.europa.eu/en/european-council/president/',
#          'display_url': 'european-council.europa.eu/en/european-co…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1184585,
#      'friends_count': 417,
#      'listed_count': 8254,
#      'created_at': 'Thu Sep 30 12:07:59 +0000 2010',
#      'favourites_count': 175,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 6599,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '002395',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334218445672624130/eDOzqi8c_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/196994616/1603972296',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 717,
#     'favorite_count': 1763,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 717,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.175,
#   'max_id': 1337164794663723014,
#   'max_id_str': '1337164794663723014',
#   'next_results': '?max_id=1337151615128772608&q=%40eucopresident&count=100&include_entities=1',
#   'query': '%40eucopresident',
#   'refresh_url': '?since_id=1337164794663723014&q=%40eucopresident&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# Set the q argument to the topic of Boris Johnson with the hashtag (or pound) # sign

TopicBoris = myTwitter.search(q = '#borisjohnson', include_rts=1, lang="fr")

TopicBoris

# you can search for tweets in a particular language, try
# DTtopic = myTwitter.search(q='#borisjohnson', include_rts=1, lang="fr")
# Out:
# {'statuses': [{'created_at': 'Thu Dec 10 22:39:48 +0000 2020',
#    'id': 1337165146238693389,
#    'id_str': '1337165146238693389',
#    'text': 'RT @Cdanslair: ▶ #Brexit : Alors #Boris, tu veux ou tu veux pas ?\n\nVous pouvez retrouver cette émission #cdanslair en podcast audio sur 4 p…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [17, 24]},
#      {'text': 'Boris', 'indices': [33, 39]},
#      {'text': 'cdanslair', 'indices': [104, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Cdanslair',
#       'name': "C dans l'air",
#       'id': 3012235893,
#       'id_str': '3012235893',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 506131716,
#     'id_str': '506131716',
#     'name': 'Judith Grohmann',
#     'screen_name': 'EmmaPeel_Knight',
#     'location': 'Vienna, Austria, Europe',
#     'description': 'Urban girl. Writer & Journalist. Biographer of @sebastiankurz. Living in Wien. Fan of London, Paris & South of France. This account is up, close & personal 😎',
#     'url': 'http://t.co/4jxgBYKoyR',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/4jxgBYKoyR',
#         'expanded_url': 'http://www.judithgrohmann.com',
#         'display_url': 'judithgrohmann.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2723,
#     'friends_count': 2967,
#     'listed_count': 92,
#     'created_at': 'Mon Feb 27 17:18:43 +0000 2012',
#     'favourites_count': 192274,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 89762,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '01090D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/655704423709052928/gokCeMGp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/655704423709052928/gokCeMGp_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/506131716/1418141602',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 11:05:45 +0000 2020',
#     'id': 1336990480761057280,
#     'id_str': '1336990480761057280',
#     'text': '▶ #Brexit : Alors #Boris, tu veux ou tu veux pas ?\n\nVous pouvez retrouver cette émission #cdanslair en podcast audi… https://t.co/7gOh2mMtVd',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Brexit', 'indices': [2, 9]},
#       {'text': 'Boris', 'indices': [18, 24]},
#       {'text': 'cdanslair', 'indices': [89, 99]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7gOh2mMtVd',
#        'expanded_url': 'https://twitter.com/i/web/status/1336990480761057280',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3012235893,
#      'id_str': '3012235893',
#      'name': "C dans l'air",
#      'screen_name': 'Cdanslair',
#      'location': 'Paris',
#      'description': "Compte officiel de l'émission présentée par @Caroline_Roux et @AxeldeTarle du lundi au samedi à 17.45 et 22.30 sur @France5tv ➡️Pour réagir : #cdanslair",
#      'url': 'https://t.co/llpeiq2qKM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/llpeiq2qKM',
#          'expanded_url': 'http://www.france.tv/france-5/c-dans-l-air/',
#          'display_url': 'france.tv/france-5/c-dan…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 73070,
#      'friends_count': 768,
#      'listed_count': 551,
#      'created_at': 'Mon Feb 02 14:20:06 +0000 2015',
#      'favourites_count': 755,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 20848,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1022862680670068737/k8vH0kk8_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022862680670068737/k8vH0kk8_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3012235893/1581613070',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 22:19:03 +0000 2020',
#    'id': 1337159921792593927,
#    'id_str': '1337159921792593927',
#    'text': 'Grande-Bretagne : #Rashford – Johnson, deux à zéro https://t.co/g32SpYrQmI\n\nLe footballeur #MarcusRashford, 23 ans,… https://t.co/1rBc7BxkwZ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Rashford', 'indices': [18, 27]},
#      {'text': 'MarcusRashford', 'indices': [91, 106]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/g32SpYrQmI',
#       'expanded_url': 'https://bit.ly/33WPstn',
#       'display_url': 'bit.ly/33WPstn',
#       'indices': [51, 74]},
#      {'url': 'https://t.co/1rBc7BxkwZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1337159921792593927',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16628468,
#     'id_str': '16628468',
#     'name': 'recriweb',
#     'screen_name': 'recriweb',
#     'location': '@LutteOuvriere',
#     'description': '“La vie est belle, une fête pr les sens. Que les générations futures la nettoient de tt mal, de tte oppression & violence & en jouissent pleinement” #Trotsky ☭',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9143,
#     'friends_count': 3235,
#     'listed_count': 389,
#     'created_at': 'Tue Oct 07 11:58:02 +0000 2008',
#     'favourites_count': 7611,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 199533,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'EEECE8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1650795540/p_fmurr08_blanc_bigger_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1650795540/p_fmurr08_blanc_bigger_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16628468/1503392197',
#     'profile_link_color': '83A5AF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '544F4F',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 20:23:24 +0000 2020',
#    'id': 1337130818402127874,
#    'id_str': '1337130818402127874',
#    'text': 'Merci ns attendons le message du pdt #Macron ..jai recu celui de #Trump de #BorisJohnson ..Ns attendons donc 🤣🤣 https://t.co/aRBHJBUVqn',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Macron', 'indices': [37, 44]},
#      {'text': 'Trump', 'indices': [65, 71]},
#      {'text': 'BorisJohnson', 'indices': [75, 88]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/aRBHJBUVqn',
#       'expanded_url': 'https://twitter.com/GDarmanin/status/1337108692391571459',
#       'display_url': 'twitter.com/GDarmanin/stat…',
#       'indices': [112, 135]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 407783867,
#     'id_str': '407783867',
#     'name': 'M.A.',
#     'screen_name': 'maxiar1',
#     'location': 'La planète ',
#     'description': "Ingénieur,  j'adore  mon pays la France que certains cherchent à détruire, social  pas Socialiste..N'est pas Français qui veut! Etre Français ça se mérite....",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 301,
#     'friends_count': 1294,
#     'listed_count': 1,
#     'created_at': 'Tue Nov 08 15:04:40 +0000 2011',
#     'favourites_count': 1072,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7872,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/846764162999111682/Ag6yRoa8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/846764162999111682/Ag6yRoa8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/407783867/1490719048',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1337108692391571459,
#    'quoted_status_id_str': '1337108692391571459',
#    'quoted_status': {'created_at': 'Thu Dec 10 18:55:29 +0000 2020',
#     'id': 1337108692391571459,
#     'id_str': '1337108692391571459',
#     'text': 'Je souhaite à tous les Juifs de France une excellente fête de Hanouka, la «\xa0fête des Lumières\xa0», symbole de joie et d’espoir.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 209825928,
#      'id_str': '209825928',
#      'name': 'Gérald DARMANIN',
#      'screen_name': 'GDarmanin',
#      'location': 'France',
#      'description': 'Ministre de l’Intérieur 🇫🇷',
#      'url': 'https://t.co/rWEKMb9EPC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/rWEKMb9EPC',
#          'expanded_url': 'https://instagram.com/gerald_darmanin?utm_source=ig_profile_share&igshid=1uc0uhbj47e7b',
#          'display_url': 'instagram.com/gerald_darmani…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 212420,
#      'friends_count': 1114,
#      'listed_count': 1254,
#      'created_at': 'Sat Oct 30 00:30:43 +0000 2010',
#      'favourites_count': 608,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 16409,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1264210301458812929/lSdKbqDR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1264210301458812929/lSdKbqDR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209825928/1594399389',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 108,
#     'favorite_count': 1030,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'fr'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 19:36:14 +0000 2020',
#    'id': 1337118950216314880,
#    'id_str': '1337118950216314880',
#    'text': "Alors que le gouvernement britannique annonçait la semaine dernière que les négociations post #Brexit avec l'UE éta… https://t.co/0chWL88GmV",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [94, 101]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/0chWL88GmV',
#       'expanded_url': 'https://twitter.com/i/web/status/1337118950216314880',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1280902937959636992,
#     'id_str': '1280902937959636992',
#     'name': 'sarah ernaux',
#     'screen_name': 'SErnaux',
#     'location': '',
#     'description': 'Je suis réaliste.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 259,
#     'friends_count': 676,
#     'listed_count': 0,
#     'created_at': 'Wed Jul 08 16:34:07 +0000 2020',
#     'favourites_count': 9,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 357,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1280903899587715079/d5R81GwF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280903899587715079/d5R81GwF_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 18:56:36 +0000 2020',
#    'id': 1337108973233856514,
#    'id_str': '1337108973233856514',
#    'text': "qu'est ce qu'ils nous font chier les Anglais  !! 3 ans et demi que ça dure , c'est intolérable d'être pris pour des… https://t.co/SyKOMmb58L",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/SyKOMmb58L',
#       'expanded_url': 'https://twitter.com/i/web/status/1337108973233856514',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 552963508,
#     'id_str': '552963508',
#     'name': 'TRANQUILLOUJN',
#     'screen_name': 'janotgwada',
#     'location': 'Hérault, Languedoc-Roussillon',
#     'description': '🌍🇫🇷  🐼 citoyen du monde libre, extrèmes barrez vous',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 838,
#     'friends_count': 541,
#     'listed_count': 3,
#     'created_at': 'Fri Apr 13 19:49:14 +0000 2012',
#     'favourites_count': 9980,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12376,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1324764261097316354/IgC-PC9Y_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1324764261097316354/IgC-PC9Y_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/552963508/1574543899',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1337089441995829249,
#    'quoted_status_id_str': '1337089441995829249',
#    'quoted_status': {'created_at': 'Thu Dec 10 17:38:59 +0000 2020',
#     'id': 1337089441995829249,
#     'id_str': '1337089441995829249',
#     'text': "🇫🇷\n#BorisJohnson continue de s'efforcer de rompre de manière litigieuse avec la #UniaoEuropeia\nLes Britanniques pai… https://t.co/hgFl4E2oSZ",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BorisJohnson', 'indices': [3, 16]},
#       {'text': 'UniaoEuropeia', 'indices': [80, 94]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/hgFl4E2oSZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1337089441995829249',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 891864061,
#      'id_str': '891864061',
#      'name': 'Orlando de Carvalho',
#      'screen_name': 'Ctk_Matem',
#      'location': '',
#      'description': 'Matemática. Catequista. Catequeta. Estudioso de temas: Pastoral, Família. Autor literário de âmbito teológico. Dirigente associativo in il tempore.',
#      'url': 'https://t.co/oyg2pTs9jM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/oyg2pTs9jM',
#          'expanded_url': 'https://www.facebook.com/orlando.decarvalho.1',
#          'display_url': 'facebook.com/orlando.decarv…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 172,
#      'friends_count': 170,
#      'listed_count': 1,
#      'created_at': 'Fri Oct 19 21:16:30 +0000 2012',
#      'favourites_count': 1333,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 8747,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/824969873168138241/-KdbruvX_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824969873168138241/-KdbruvX_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/891864061/1548343323',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 18:56:20 +0000 2020',
#    'id': 1337108906657656835,
#    'id_str': '1337108906657656835',
#    'text': '#BrexitNoDeal : n-ième faux rebondissement sur un constat de défiance qui a provoqué les résultats du référendum de… https://t.co/w7zw3KmVaG',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'BrexitNoDeal', 'indices': [0, 13]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/w7zw3KmVaG',
#       'expanded_url': 'https://twitter.com/i/web/status/1337108906657656835',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2671340704,
#     'id_str': '2671340704',
#     'name': 'Pierre Praxton',
#     'screen_name': 'PPraxton',
#     'location': 'Charenton-le-Pont, Ile-de-France',
#     'description': "#geek de 1955, ayant aussi commencé au fond d'un garage, consultant indépendant pour ne pas contraindre sa parole au prix de sa gamelle.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 51,
#     'friends_count': 26,
#     'listed_count': 9,
#     'created_at': 'Fri Jul 04 09:45:29 +0000 2014',
#     'favourites_count': 2925,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2443,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/484997137294700544/83911_PD_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/484997137294700544/83911_PD_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2671340704/1404467304',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 17:38:59 +0000 2020',
#    'id': 1337089441995829249,
#    'id_str': '1337089441995829249',
#    'text': "🇫🇷\n#BorisJohnson continue de s'efforcer de rompre de manière litigieuse avec la #UniaoEuropeia\nLes Britanniques pai… https://t.co/hgFl4E2oSZ",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'BorisJohnson', 'indices': [3, 16]},
#      {'text': 'UniaoEuropeia', 'indices': [80, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/hgFl4E2oSZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1337089441995829249',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 891864061,
#     'id_str': '891864061',
#     'name': 'Orlando de Carvalho',
#     'screen_name': 'Ctk_Matem',
#     'location': '',
#     'description': 'Matemática. Catequista. Catequeta. Estudioso de temas: Pastoral, Família. Autor literário de âmbito teológico. Dirigente associativo in il tempore.',
#     'url': 'https://t.co/oyg2pTs9jM',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/oyg2pTs9jM',
#         'expanded_url': 'https://www.facebook.com/orlando.decarvalho.1',
#         'display_url': 'facebook.com/orlando.decarv…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 172,
#     'friends_count': 170,
#     'listed_count': 1,
#     'created_at': 'Fri Oct 19 21:16:30 +0000 2012',
#     'favourites_count': 1333,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8747,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/824969873168138241/-KdbruvX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824969873168138241/-KdbruvX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/891864061/1548343323',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 16:50:24 +0000 2020',
#    'id': 1337077214148440065,
#    'id_str': '1337077214148440065',
#    'text': "Il semble que le #Brexit se présente mal ! Les exigences de #BorisJohnson sont hégémoniques ! Pour la pêche c'est s… https://t.co/K00sYxMP8U",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [17, 24]},
#      {'text': 'BorisJohnson', 'indices': [60, 73]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/K00sYxMP8U',
#       'expanded_url': 'https://twitter.com/i/web/status/1337077214148440065',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 571663039,
#     'id_str': '571663039',
#     'name': 'Anselme 2 Villeneuve',
#     'screen_name': 'Anselmedevil',
#     'location': 'FRANCE',
#     'description': "La dérision, c'est le salut du monde. Rien n'est important, tout est insignifiant, la vie est farce. Seule compte la grandeur de la France !",
#     'url': 'http://t.co/cI1ooTMAZ4',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/cI1ooTMAZ4',
#         'expanded_url': 'http://blagues-de-nuls.over-blog.com',
#         'display_url': 'blagues-de-nuls.over-blog.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3828,
#     'friends_count': 4406,
#     'listed_count': 46,
#     'created_at': 'Sat May 05 11:14:07 +0000 2012',
#     'favourites_count': 32,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 47538,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2223180251/IMG_0800_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2223180251/IMG_0800_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/571663039/1400602394',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 16:31:14 +0000 2020',
#    'id': 1337072390933630977,
#    'id_str': '1337072390933630977',
#    'text': 'Bizarre fellow #BorisJohnson https://t.co/00YY7ilopG',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BorisJohnson', 'indices': [15, 28]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/00YY7ilopG',
#       'expanded_url': 'https://twitter.com/bsindia/status/1337063272495910913',
#       'display_url': 'twitter.com/bsindia/status…',
#       'indices': [29, 52]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 450497116,
#     'id_str': '450497116',
#     'name': 'उदित UDIT',
#     'screen_name': 'UditSheth',
#     'location': '',
#     'description': 'entrepreneur. strategist. diver. leader. creator',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1151,
#     'friends_count': 649,
#     'listed_count': 55,
#     'created_at': 'Fri Dec 30 09:21:34 +0000 2011',
#     'favourites_count': 8797,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12555,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFF04D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1311361003465052162/4kEAVHdJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311361003465052162/4kEAVHdJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/450497116/1597123159',
#     'profile_link_color': '0099CC',
#     'profile_sidebar_border_color': 'FFF8AD',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1337063272495910913,
#    'quoted_status_id_str': '1337063272495910913',
#    'quoted_status': {'created_at': 'Thu Dec 10 15:55:00 +0000 2020',
#     'id': 1337063272495910913,
#     'id_str': '1337063272495910913',
#     'text': 'WATCH | UK PM Boris Johnson confuses farmer protest with India-Pakistan dispute \n\nFull video here: \n\n#FarmBill2020… https://t.co/JEVcifNTyE',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'FarmBill2020', 'indices': [101, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JEVcifNTyE',
#        'expanded_url': 'https://twitter.com/i/web/status/1337063272495910913',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 43855487,
#      'id_str': '43855487',
#      'name': 'Business Standard',
#      'screen_name': 'bsindia',
#      'location': 'India',
#      'description': "Latest updates #news #LIVE coverage on #economy #companies #markets #politics and #technology from India's leading business daily\nhttps://t.co/VVl6HGuvvc",
#      'url': 'https://t.co/bXS4j8yx1g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/bXS4j8yx1g',
#          'expanded_url': 'http://www.business-standard.com',
#          'display_url': 'business-standard.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/VVl6HGuvvc',
#          'expanded_url': 'http://t.me/bsindiaofficial',
#          'display_url': 't.me/bsindiaofficial',
#          'indices': [130, 153]}]}},
#      'protected': False,
#      'followers_count': 2034778,
#      'friends_count': 377,
#      'listed_count': 3120,
#      'created_at': 'Mon Jun 01 08:52:08 +0000 2009',
#      'favourites_count': 186,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 314586,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '9AE4E8',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1194080296821559296/4GUNRuCM_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194080296821559296/4GUNRuCM_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43855487/1607067453',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'CECECE',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 16:13:44 +0000 2020',
#    'id': 1337067986855878661,
#    'id_str': '1337067986855878661',
#    'text': 'RT @France24_fr: Négociations post-#Brexit 🇬🇧 🇪🇺 : après leur rencontre à #Bruxelles, #BorisJohnson et Ursula von der Leyen ont décidé de s…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [35, 42]},
#      {'text': 'Bruxelles', 'indices': [74, 84]},
#      {'text': 'BorisJohnson', 'indices': [86, 99]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'France24_fr',
#       'name': 'FRANCE 24 Français',
#       'id': 25048816,
#       'id_str': '25048816',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 944198191918075904,
#     'id_str': '944198191918075904',
#     'name': 'arezkimekebbel@gmail.com',
#     'screen_name': 'arezkimekebbel',
#     'location': '',
#     'description': 'Actualités',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2350,
#     'friends_count': 5001,
#     'listed_count': 3,
#     'created_at': 'Fri Dec 22 13:29:26 +0000 2017',
#     'favourites_count': 45336,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29332,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/946001037902667776/x9MCykVK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/946001037902667776/x9MCykVK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/944198191918075904/1603470743',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 10:20:00 +0000 2020',
#     'id': 1336978967014752259,
#     'id_str': '1336978967014752259',
#     'text': 'Négociations post-#Brexit 🇬🇧 🇪🇺 : après leur rencontre à #Bruxelles, #BorisJohnson et Ursula von der Leyen ont déci… https://t.co/JOFtpGeBry',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Brexit', 'indices': [18, 25]},
#       {'text': 'Bruxelles', 'indices': [57, 67]},
#       {'text': 'BorisJohnson', 'indices': [69, 82]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JOFtpGeBry',
#        'expanded_url': 'https://twitter.com/i/web/status/1336978967014752259',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 25048816,
#      'id_str': '25048816',
#      'name': 'FRANCE 24 Français',
#      'screen_name': 'France24_fr',
#      'location': 'Paris, France',
#      'description': "🌍 La chaîne française d'information internationale @FRANCE24 en français - Suivez toute l'actualité du monde en #Direct - 🔴 Alertes Info : @UrgentF24",
#      'url': 'https://t.co/LuWTTtWyJg',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LuWTTtWyJg',
#          'expanded_url': 'https://www.france24.com/fr/',
#          'display_url': 'france24.com/fr/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3612081,
#      'friends_count': 1428,
#      'listed_count': 5869,
#      'created_at': 'Wed Mar 18 09:18:58 +0000 2009',
#      'favourites_count': 1071,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 162080,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25048816/1601912014',
#      'profile_link_color': '00A7E3',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'CADAEB',
#      'profile_text_color': '125A95',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 61,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 15:33:37 +0000 2020',
#    'id': 1337057892361510915,
#    'id_str': '1337057892361510915',
#    'text': 'RT @France24_fr: Négociations post-#Brexit 🇬🇧 🇪🇺 : après leur rencontre à #Bruxelles, #BorisJohnson et Ursula von der Leyen ont décidé de s…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [35, 42]},
#      {'text': 'Bruxelles', 'indices': [74, 84]},
#      {'text': 'BorisJohnson', 'indices': [86, 99]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'France24_fr',
# ...
#      'url': 'https://t.co/LuWTTtWyJg',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LuWTTtWyJg',
#          'expanded_url': 'https://www.france24.com/fr/',
#          'display_url': 'france24.com/fr/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3612081,
#      'friends_count': 1428,
#      'listed_count': 5869,
#      'created_at': 'Wed Mar 18 09:18:58 +0000 2009',
#      'favourites_count': 1071,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 162080,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25048816/1601912014',
#      'profile_link_color': '00A7E3',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'CADAEB',
#      'profile_text_color': '125A95',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 61,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 14:57:23 +0000 2020',
#    'id': 1337048773458096129,
#    'id_str': '1337048773458096129',
#    'text': 'RT @France24_fr: Négociations post-#Brexit 🇬🇧 🇪🇺 : après leur rencontre à #Bruxelles, #BorisJohnson et Ursula von der Leyen ont décidé de s…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [35, 42]},
#      {'text': 'Bruxelles', 'indices': [74, 84]},
#      {'text': 'BorisJohnson', 'indices': [86, 99]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'France24_fr',
#       'name': 'FRANCE 24 Français',
#       'id': 25048816,
#       'id_str': '25048816',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 28468899,
#     'id_str': '28468899',
#     'name': 'Jim Pereira',
#     'screen_name': 'jimpereiraRG',
#     'location': 'Rio de Janeiro, Brasil',
#     'description': "Ex-Comissário de voo Varig, Jornalista, Membro Fundador do Movimento ACORDO JÁ!, e Editor da revista virtual 'O cão que fuma'.",
#     'url': 'http://t.co/u2l1T41bCg',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/u2l1T41bCg',
#         'expanded_url': 'http://www.caoquefuma.com',
#         'display_url': 'caoquefuma.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4383,
#     'friends_count': 75,
#     'listed_count': 18,
#     'created_at': 'Fri Apr 03 01:20:25 +0000 2009',
#     'favourites_count': 377,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 106405,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1058755353750523904/VDcAtBSd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1058755353750523904/VDcAtBSd_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28468899/1444049257',
#     'profile_link_color': '15C2C2',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 10:20:00 +0000 2020',
#     'id': 1336978967014752259,
#     'id_str': '1336978967014752259',
#     'text': 'Négociations post-#Brexit 🇬🇧 🇪🇺 : après leur rencontre à #Bruxelles, #BorisJohnson et Ursula von der Leyen ont déci… https://t.co/JOFtpGeBry',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Brexit', 'indices': [18, 25]},
#       {'text': 'Bruxelles', 'indices': [57, 67]},
#       {'text': 'BorisJohnson', 'indices': [69, 82]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JOFtpGeBry',
#        'expanded_url': 'https://twitter.com/i/web/status/1336978967014752259',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 25048816,
#      'id_str': '25048816',
#      'name': 'FRANCE 24 Français',
#      'screen_name': 'France24_fr',
#      'location': 'Paris, France',
#      'description': "🌍 La chaîne française d'information internationale @FRANCE24 en français - Suivez toute l'actualité du monde en #Direct - 🔴 Alertes Info : @UrgentF24",
#      'url': 'https://t.co/LuWTTtWyJg',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/LuWTTtWyJg',
#          'expanded_url': 'https://www.france24.com/fr/',
#          'display_url': 'france24.com/fr/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3612081,
#      'friends_count': 1428,
#      'listed_count': 5869,
#      'created_at': 'Wed Mar 18 09:18:58 +0000 2009',
#      'favourites_count': 1071,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 162080,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875647914747469824/RLD9u2W9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25048816/1601912014',
#      'profile_link_color': '00A7E3',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'CADAEB',
#      'profile_text_color': '125A95',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 61,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'},
#   {'created_at': 'Thu Dec 10 14:13:43 +0000 2020',
#    'id': 1337037785006530560,
#    'id_str': '1337037785006530560',
#    'text': 'RT @Cdanslair: ▶ #Brexit : Alors #Boris, tu veux ou tu veux pas ?\n\nVous pouvez retrouver cette émission #cdanslair en podcast audio sur 4 p…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Brexit', 'indices': [17, 24]},
#      {'text': 'Boris', 'indices': [33, 39]},
#      {'text': 'cdanslair', 'indices': [104, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Cdanslair',
#       'name': "C dans l'air",
#       'id': 3012235893,
#       'id_str': '3012235893',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 15741261,
#     'id_str': '15741261',
#     'name': 'Anne-Elisabeth Moutet',
#     'screen_name': 'moutet',
#     'location': 'Paris',
#     'description': 'Telegraph, 28Minutes ARTE TV, UnHerd, CapX, BBC, New York Post; adopted by two cats, one wheeled suitcase, and a tall dark stranger. Blocked by @georgegalloway.',
#     'url': 'https://t.co/4tUTT3U0S7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/4tUTT3U0S7',
#         'expanded_url': 'https://www.telegraph.co.uk/authors/anne-elisabeth-moutet/',
#         'display_url': 'telegraph.co.uk/authors/anne-e…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14916,
#     'friends_count': 4795,
#     'listed_count': 343,
#     'created_at': 'Tue Aug 05 20:26:29 +0000 2008',
#     'favourites_count': 109084,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 152835,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3220615207/f5de31bd438f7f90b64a633452f3a6e2_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3220615207/f5de31bd438f7f90b64a633452f3a6e2_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15741261/1398444550',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 10 11:05:45 +0000 2020',
#     'id': 1336990480761057280,
#     'id_str': '1336990480761057280',
#     'text': '▶ #Brexit : Alors #Boris, tu veux ou tu veux pas ?\n\nVous pouvez retrouver cette émission #cdanslair en podcast audi… https://t.co/7gOh2mMtVd',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Brexit', 'indices': [2, 9]},
#       {'text': 'Boris', 'indices': [18, 24]},
#       {'text': 'cdanslair', 'indices': [89, 99]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7gOh2mMtVd',
#        'expanded_url': 'https://twitter.com/i/web/status/1336990480761057280',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3012235893,
#      'id_str': '3012235893',
#      'name': "C dans l'air",
#      'screen_name': 'Cdanslair',
#      'location': 'Paris',
#      'description': "Compte officiel de l'émission présentée par @Caroline_Roux et @AxeldeTarle du lundi au samedi à 17.45 et 22.30 sur @France5tv ➡️Pour réagir : #cdanslair",
#      'url': 'https://t.co/llpeiq2qKM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/llpeiq2qKM',
#          'expanded_url': 'http://www.france.tv/france-5/c-dans-l-air/',
#          'display_url': 'france.tv/france-5/c-dan…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 73070,
#      'friends_count': 768,
#      'listed_count': 551,
#      'created_at': 'Mon Feb 02 14:20:06 +0000 2015',
#      'favourites_count': 755,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 20848,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1022862680670068737/k8vH0kk8_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022862680670068737/k8vH0kk8_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3012235893/1581613070',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fr'}],
#  'search_metadata': {'completed_in': 0.177,
#   'max_id': 1337165146238693389,
#   'max_id_str': '1337165146238693389',
#   'next_results': '?max_id=1337037785006530559&q=%23borisjohnson&lang=fr&include_entities=1',
#   'query': '%23borisjohnson',
#   'refresh_url': '?since_id=1337165146238693389&q=%23borisjohnson&lang=fr&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
